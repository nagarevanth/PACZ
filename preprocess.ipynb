# %%
import numpy as np
import pandas as pd
import networkx as nx
import matplotlib.pyplot as plt
import re

# %%
initial_dataset = 'datasets/emails.csv'
cleaned_dataset = 'datasets/emails_cleaned.csv'
sample_dataset = 'datasets/sample_emails.csv' # this contains with hierarchial order

# %%
df = pd.read_csv(initial_dataset)
df.head(5)
# Out:
#                        file                                            message
# 0     allen-p/_sent_mail/1.  Message-ID: <18782981.1075855378110.JavaMail.e...
# 1    allen-p/_sent_mail/10.  Message-ID: <15464986.1075855378456.JavaMail.e...
# 2   allen-p/_sent_mail/100.  Message-ID: <24216240.1075855687451.JavaMail.e...
# 3  allen-p/_sent_mail/1000.  Message-ID: <13505866.1075863688222.JavaMail.e...
# 4  allen-p/_sent_mail/1001.  Message-ID: <30922949.1075863688243.JavaMail.e...

# %%
print(df.iloc[22,1])
# Out:
# Message-ID: <26575732.1075855687756.JavaMail.evans@thyme>
# Date: Mon, 2 Oct 2000 02:19:00 -0700 (PDT)
# From: phillip.allen@enron.com
# To: bs_stone@yahoo.com
# Subject: Re: Original Sept check/closing
# Mime-Version: 1.0
# Content-Type: text/plain; charset=us-ascii
# Content-Transfer-Encoding: 7bit
# X-From: Phillip K Allen
# X-To: "BS Stone" <bs_stone@yahoo.com> @ ENRON
# X-cc:
# X-bcc:
# X-Folder: \Phillip_Allen_Dec2000\Notes Folders\'sent mail
# X-Origin: Allen-P
# X-FileName: pallen.nsf
#
# Brenda,
#
#  Please use the second check as my October payment.  I have my copy of the
# original deal.  Do you want me to fax this to you?
#
# Phillip

# %%
def info_part(i):
    """split infomation part out"""
    return i.split('\n\n', 1)[0]
def content_part(i):
    """split content part out"""
    return i.split('\n\n', 1)[1]
df['pre_info'] = df.message.map(info_part)
df['content'] = df.message.map(content_part)
df['test_true'] = True

words2split = ['Message-ID: ', 'Date: ', 'From: ', 'To: ', 'Subject: ', 'Cc: ', 'Mime-Version: ', 'Content-Type: ',
               'Content-Transfer-Encoding: ', 'Bcc: ', 'X-From: ', 'X-To: ', 'X-cc: ', 'X-bcc: ', 'X-Folder: ', 'X-Origin: ',
               'X-FileName: ']
features_naming = [i[:-2] for i in words2split]
split_condition = '|'.join(words2split)

# %%
# Some emails' subject confuse the string-spliting function, so I make a little change
def duplicated_info(i):
    return i.replace(' Date: ', ' Date- ').replace(' Subject: ', ' Subject2: ').replace(' To: ',
                    ' To- ').replace(' (Subject: ', ' (Subject- ')
df['pre_info'] = df['pre_info'].map(duplicated_info)

# let's check how many categories are there in these emails
def num_part(i):
    return len(re.split(split_condition, i))
df['num_info'] = df['pre_info'].map(num_part)

# around 20k emails do not have the 'To: ' category, so I add one
def add_to(i):
    return i.replace('\nSubject: ', '\nTo: \nSubject: ')
temp_condition = (df['num_info'] == 17) | (df['num_info'] == 15)
df.loc[temp_condition, 'pre_info'] = df.loc[temp_condition, 'pre_info'].map(add_to)


# similar way to deal with the "Cc:" and "Bcc:" categories
temp_condition = (df['num_info'] == 16) | (df['num_info'] == 15)
def add_bcc(i):
    return i.replace('\nX-From: ', '\nBcc: \nX-From: ')
df.loc[temp_condition, 'pre_info'] = df.loc[temp_condition, 'pre_info'].map(add_bcc)
def add_cc(i):
    return i.replace('\nMime-Version: ', '\nCc: \nMime-Version: ')
df.loc[temp_condition, 'pre_info'] = df.loc[temp_condition, 'pre_info'].map(add_cc)

# %%
df['num_info'] = df['pre_info'].map(num_part)
df['num_info'].value_counts()
# Out:
# num_info
# 18    517398
# 5          2
# 6          1
# Name: count, dtype: int64

# %%
df_remove = df.loc[df['num_info'] != 18].copy()
df = df.loc[df['num_info'] == 18].copy()

# %%
global feature_idx
def info_split(i):
    ## split the i th part out and remove \n for the feature
    return re.split(split_condition, i)[feature_idx+1][:-2]
def info_split_last(i):
    ## no need to remove \n for last category -- X-FileName
    return re.split(split_condition, i)[feature_idx+1]
for feature_idx in range(len(words2split)):
    if feature_idx != len(words2split) - 1:
        df[features_naming[feature_idx]] = df['pre_info'].map(info_split)
    else:
        df[features_naming[feature_idx]] = df['pre_info'].map(info_split_last)

# %%
df['Content-Transfer-Encoding'].value_counts()
# Out:
# Content-Transfer-Encoding
# 7bi                            494994
# quoted-printabl                 22399
# base6                               4
# text/plain; charset=us-asci         1
# Name: count, dtype: int64

# %%
df_remove2 = df.loc[df['Content-Transfer-Encoding'] == 'text/plain; charset=us-asci']
df = df.loc[df['Content-Transfer-Encoding'] != 'text/plain; charset=us-asci']

# %%
def split_other_content(i):
    """split other forms of contents out"""
    return i.split('-------------', 1)[0]
df["has_other_content"] = df["content"].str.contains("-------------")
df["if_forwarded"] = df["content"].str.contains("------------- Forwarded")
df['content'] = df.content.map(split_other_content)

# %%
df = df.drop(['pre_info','test_true', 'num_info'], axis = 1).set_index("file")
df.to_csv(cleaned_dataset, index = False)

# %%
df = pd.read_csv(cleaned_dataset)
df['Main_To'] = df['To'].astype(str).str.split(',').str[0].str.strip()

df.head(5)
# Out:
#                                              message  \
# 0  Message-ID: <18782981.1075855378110.JavaMail.e...
# 1  Message-ID: <15464986.1075855378456.JavaMail.e...
# 2  Message-ID: <24216240.1075855687451.JavaMail.e...
# 3  Message-ID: <13505866.1075863688222.JavaMail.e...
# 4  Message-ID: <30922949.1075863688243.JavaMail.e...
#
#                                              content  \
# 0                          Here is our forecast\n\n
# 1  Traveling to have a business meeting takes the...
# 2                     test successful.  way to go!!!
# 3  Randy,\n\n Can you send me a schedule of the s...
# 4                Let's shoot for Tuesday at 11:45.
#
#                                      Message-ID  \
# 0  <18782981.1075855378110.JavaMail.evans@thyme
# 1  <15464986.1075855378456.JavaMail.evans@thyme
# 2  <24216240.1075855687451.JavaMail.evans@thyme
# 3  <13505866.1075863688222.JavaMail.evans@thyme
# 4  <30922949.1075863688243.JavaMail.evans@thyme
#
#                                    Date                    From  \
# 0  Mon, 14 May 2001 16:39:00 -0700 (PDT  phillip.allen@enron.co
# 1   Fri, 4 May 2001 13:51:00 -0700 (PDT  phillip.allen@enron.co
# 2  Wed, 18 Oct 2000 03:00:00 -0700 (PDT  phillip.allen@enron.co
# 3  Mon, 23 Oct 2000 06:13:00 -0700 (PDT  phillip.allen@enron.co
# 4  Thu, 31 Aug 2000 05:07:00 -0700 (PDT  phillip.allen@enron.co
#
#                        To   Subject   Cc  Mime-Version  \
# 0     tim.belden@enron.co       NaN  NaN           1.0
# 1  john.lavorato@enron.co        Re  NaN           1.0
# 2   leah.arsdall@enron.co   Re: tes  NaN           1.0
# 3    randall.gay@enron.co       NaN  NaN           1.0
# 4     greg.piper@enron.co  Re: Hell  NaN           1.0
#
#                   Content-Type  ...          X-From  \
# 0  text/plain; charset=us-asci  ...  Phillip K Alle
# 1  text/plain; charset=us-asci  ...  Phillip K Alle
# 2  text/plain; charset=us-asci  ...  Phillip K Alle
# 3  text/plain; charset=us-asci  ...  Phillip K Alle
# 4  text/plain; charset=us-asci  ...  Phillip K Alle
#
#                                                 X-To X-cc X-bcc  \
# 0            Tim Belden <Tim Belden/Enron@EnronXGate  NaN   NaN
# 1  John J Lavorato <John J Lavorato/ENRON@enronXg...  NaN   NaN
# 2                                    Leah Van Arsdal  NaN   NaN
# 3                                       Randall L Ga  NaN   NaN
# 4                                          Greg Pipe  NaN   NaN
#
#                                             X-Folder X-Origin  \
# 0  \Phillip_Allen_Jan2002_1\Allen, Phillip K.\'Se...   Allen-
# 1  \Phillip_Allen_Jan2002_1\Allen, Phillip K.\'Se...   Allen-
# 2     \Phillip_Allen_Dec2000\Notes Folders\'sent mai   Allen-
# 3     \Phillip_Allen_Dec2000\Notes Folders\'sent mai   Allen-
# 4     \Phillip_Allen_Dec2000\Notes Folders\'sent mai   Allen-
#
#                     X-FileName has_other_content if_forwarded  \
# 0  pallen (Non-Privileged).pst             False        False
# 1  pallen (Non-Privileged).pst             False        False
# 2                   pallen.nsf             False        False
# 3                   pallen.nsf             False        False
# 4                   pallen.nsf             False        False
#
#                   Main_To
# 0     tim.belden@enron.co
# 1  john.lavorato@enron.co
# 2   leah.arsdall@enron.co
# 3    randall.gay@enron.co
# 4     greg.piper@enron.co
#
# [5 rows x 22 columns]

# %%
filtered_df = df[(df['has_other_content'] == False) & (df['if_forwarded'] == False)]
# remove the rows if there are less than 2 " " in the content
print(f"Total rows: {len(filtered_df)}")
for i in range(50):
    # print the content of the first 50 emails
    print(f"Email {i+1}:")
    print("--------------------------------------------------")
    print(filtered_df.iloc[i]['content'])
    print("--------------------------------------------------")
# Out:
# Total rows: 420037
# Email 1:
# --------------------------------------------------
# Here is our forecast
#
#
# --------------------------------------------------
# Email 2:
# --------------------------------------------------
# Traveling to have a business meeting takes the fun out of the trip.  Especially if you have to prepare a presentation.  I would suggest holding the business plan meetings here then take a trip without any formal business meetings.  I would even try and get some honest opinions on whether a trip is even desired or necessary.
#
# As far as the business meetings, I think it would be more productive to try and stimulate discussions across the different groups about what is working and what is not.  Too often the presenter speaks and the others are quiet just waiting for their turn.   The meetings might be better if held in a round table discussion format.
#
# My suggestion for where to go is Austin.  Play golf and rent a ski boat and jet ski's.  Flying somewhere takes too much time.
#
# --------------------------------------------------
# Email 3:
# --------------------------------------------------
# test successful.  way to go!!!
# --------------------------------------------------
# Email 4:
# --------------------------------------------------
# Randy,
#
#  Can you send me a schedule of the salary and level of everyone in the
# scheduling group.  Plus your thoughts on any changes that need to be made.
# (Patti S for example)
#
# Phillip
# --------------------------------------------------
# Email 5:
# --------------------------------------------------
# Let's shoot for Tuesday at 11:45.
# --------------------------------------------------
# Email 6:
# --------------------------------------------------
# Greg,
#
#  How about either next Tuesday or Thursday?
#
# Phillip
# --------------------------------------------------
# Email 7:
# --------------------------------------------------
# Please cc the following distribution list with updates:
#
# Phillip Allen (pallen@enron.com)
# Mike Grigsby (mike.grigsby@enron.com)
# Keith Holst (kholst@enron.com)
# Monique Sanchez
# Frank Ermis
# John Lavorato
#
#
# Thank you for your help
#
# Phillip Allen
#
# --------------------------------------------------
# Email 8:
# --------------------------------------------------
# any morning between 10 and 11:30
# --------------------------------------------------
# Email 9:
# --------------------------------------------------
# 1. login:  pallen pw: ke9davis
#
#  I don't think these are required by the ISP
#
#   2.  static IP address
#
#  IP: 64.216.90.105
#  Sub: 255.255.255.248
#  gate: 64.216.90.110
#  DNS: 151.164.1.8
#
#   3.  Company: 0413
#         RC:  105891
# --------------------------------------------------
# Email 10:
# --------------------------------------------------
# Mr. Buckner,
#
#  For delivered gas behind San Diego, Enron Energy Services is the appropriate
# Enron entity.  I have forwarded your request to Zarin Imam at EES.  Her phone
# number is 713-853-7107.
#
# Phillip Allen
# --------------------------------------------------
# Email 11:
# --------------------------------------------------
# Lucy,
#
#  Here are the rentrolls:
#
#
#
#  Open them and save in the rentroll folder.  Follow these steps so you don't
# misplace these files.
#
#  1.  Click on Save As
#  2.  Click on the drop down triangle under Save in:
#  3.  Click on the  (C): drive
#  4.  Click on the appropriate folder
#  5.  Click on Save:
#
# Phillip
# --------------------------------------------------
# Email 12:
# --------------------------------------------------
# Dave,
#
#  Here are the names of the west desk members by category.  The origination
# side is very sparse.
#
#
#
#
#
# Phillip
#
# --------------------------------------------------
# Email 13:
# --------------------------------------------------
# Paula,
#
#  35 million is fine
#
# Phillip
# --------------------------------------------------
# Email 14:
# --------------------------------------------------
# Tim,
#
# mike grigsby is having problems with accessing the west power site.  Can you please make sure he has an active password.
#
# Thank you,
#
# Phillip
# --------------------------------------------------
# Email 15:
# --------------------------------------------------
# Brenda,
#
# Please use the second check as the October payment.  If you have already
# tossed it, let me know so I can mail you another.
#
# Phillip
# --------------------------------------------------
# Email 16:
# --------------------------------------------------
# I think Fletch has a good CPA.  I am still doing my own.
# --------------------------------------------------
# Email 17:
# --------------------------------------------------
# Brenda,
#
#  Please use the second check as my October payment.  I have my copy of the
# original deal.  Do you want me to fax this to you?
#
# Phillip
# --------------------------------------------------
# Email 18:
# --------------------------------------------------
# Liane,
#
#  As we discussed yesterday, I am concerned there has been an attempt to
# manipulate the  El Paso San Juan monthly index.  A single buyer entered the
# marketplace on both September 26 and 27 and paid above market prices
# ($4.70-$4.80) for San Juan gas with the intent to distort the index.  At the
# time of these trades, offers for physical gas at significantly (10 to 15
# cents) lower prices were bypassed in order to establish higher trades to
# report into the index calculation.  Additionally, these trades are out of
# line with the associated financial swaps for San Juan.
#
#  We have compiled a list of financial and physical trades executed from
# September 25 to September 27.  These are the complete list of trades from
# Enron Online (EOL), Enron's direct phone conversations, and three brokerage
# firms (Amerex, APB, and Prebon).  Please see the attached spreadsheet for a
# trade by trade list and a summary.  We have also included a summary of gas
# daily prices to illustrate the value of San Juan based on several spread
# relationships.  The two key points from this data are as follows:
#
#  1.  The high physical prices on the 26th & 27th (4.75,4,80) are much greater
# than the high financial trades (4.6375,4.665) on those days.
#
#  2.  The spread relationship between San Juan and other points (Socal &
# Northwest)  is  consistent between the end of September and
#        October gas daily.  It doesn't make sense to have monthly indeces that
# are dramatically different.
#
#
#  I understand you review the trades submitted for outliers.  Hopefully, the
# trades submitted will reveal counterparty names and you will be able to
# determine that there was only one buyer in the 4.70's and these trades are
# outliers.  I wanted to give you some additional points of reference to aid in
# establishing a reasonable index.  It is Enron's belief that the trades at
# $4.70 and higher  were above market trades that should be excluded from the
# calculation of index.
#
#  It is our desire to have reliable and accurate indeces against which to
# conduct our physical and financial business.  Please contact me
# anytime I can assist you towards this goal.
#
# Sincerely,
#
# Phillip Allen
#
# --------------------------------------------------
# Email 19:
# --------------------------------------------------
# Reagan,
#
# Just wanted to give you an update.  I have changed the unit mix to include some 1 bedrooms and reduced the number of buildings to 12.  Kipp Flores is working on the construction drawings.  At the same time I am pursuing FHA financing.  Once the construction drawings are complete I will send them to you for a revised bid.  Your original bid was competitive and I am still attracted to your firm because of your strong local presence and contacts.
#
# Phillip
# --------------------------------------------------
# Email 20:
# --------------------------------------------------
# Nymex expiration is during this time frame.  Please reschedule.
# --------------------------------------------------
# Email 21:
# --------------------------------------------------
# Chris,
#
#  What is the latest with PG&E?  We have been having good discussions
# regarding EOL.
#  Call me when you can. X37041
#
# Phillip
# --------------------------------------------------
# Email 22:
# --------------------------------------------------
# Greg,
#
# Happy B-day. Email me your phone # and I will call you.
#
# Keith
# --------------------------------------------------
# Email 23:
# --------------------------------------------------
# Kathy,
#
# Regarding the guest password for gas daily, can you please relay the
# information to Mike Grigsby at 37031 so he can pass it along to the user at
# gas daily today.  I will be out of the office on Friday.
#
# thank you
#
# Phillip
# --------------------------------------------------
# Email 24:
# --------------------------------------------------
# John,
#
#  Denver's short rockies position  beyond 2002 is created by their Trailblazer
# transport.  They are unhedged 15,000/d in 2003 and 25,000/d in 2004 and
# 2005.
#
#  They are scrubbing all their books and booking the Hubert deal on Wednesday
# and Thursday.
#
# Phillip
# --------------------------------------------------
# Email 25:
# --------------------------------------------------
# Jim,
#
# Is there going to be a conference call or some type of weekly meeting about all the regulatory issues facing California this week?  Can you make sure the gas desk is included.
#
# Phillip
# --------------------------------------------------
# Email 26:
# --------------------------------------------------
# George,
#
#  Below is a list of questions that Keith and I had regarding the Westgate
# project:
#
#  Ownership Structure
#
#  What will be the ownership structure? Limited partnership? General partner?
#
#  What are all the legal entities that will be involved and in what
# capacity(regarding ownership and
#  liabilities)?
#
#  Who owns the land? improvements?
#
#  Who holds the various loans?
#
#  Is the land collateral?
#
#  Investment
#
#  What happens to initial investment?
#
#  Is it used to purchase land for cash?Secure future loans?
#
#  Why is the land cost spread out on the cash flow statement?
#
#  When is the 700,000 actually needed? Now or for the land closing? Investment
# schedule?
#
#  Investment Return
#
#  Is Equity Repayment the return of the original investment?
#
#  Is the plan to wait until the last unit is sold and closed before profits
# are distributed?
#
#  Debt
#
#  Which entity is the borrower for each loan and what recourse or collateral
# is associated with each
#  loan?
#
#  Improvement
#
#  Construction
#
#  Are these the only two loans?  Looks like it from the cash flow statement.
#
#  Terms of each loan?
#
#  Uses of Funds
#
#  How will disbursements be made?  By whom?
#
#  What type of bank account?  Controls on max disbursement? Internet viewing
# for investors?
#
#  Reports to track expenses vs plan?
#
#  Bookkeeping procedures to record actual expenses?
#
#  What is the relationship of Creekside Builders to the project?  Do you get
# paid a markup on subcontractors as a
#  general contractor and paid gain out of profits?
#
#  Do you or Larry receive any money in the form of salary or personal expenses
# before the ultimate payout of profits?
#
#  Design and Construction
#
#  When will design be complete?
#
#  What input will investors have in selecting design and materials for units?
#
#  What level of investor involvement will be possible during construction
# planning and permitting?
#
#  Does Creekside have specific procedures for dealing with subcontractors,
# vendors, and other professionals?
#  Such as always getting 3 bids, payment schedules, or reference checking?
#
#  Are there any specific companies or individuals that you already plan to
# use? Names?
#
# These questions are probably very basic to you, but as a first time investor
# in a project like this it is new to me.  Also, I want to learn as
# much as possible from the process.
#
# Phillip
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# --------------------------------------------------
# Email 27:
# --------------------------------------------------
# George,
#
#  Here sales numbers from Reagan:
#
#
#
#
#  As you can see his units sold at a variety of prices per square foot.  The
# 1308/1308 model seems to have the most data and looks most similiar to the
# units you are selling.  At  2.7 MM, my bid is .70/sf higher than his units
# under construction.  I am having a hard time justifying paying much more with
# competition on the way.  The price I am bidding is higher than any deals
# actually done to date.
#
#  Let me know what you think.  I will follow up with an email and phone call
# about Cherry Creek.  I am sure Deborah Yates let you know that the bid was
# rejected on the De Ville property.
#
# Phillip Allen
#
#
#
#
#
#
#
# --------------------------------------------------
# Email 28:
# --------------------------------------------------
# Jeff,
#
#  What is up with Burnet?
#
# Phillip
# --------------------------------------------------
# Email 29:
# --------------------------------------------------
# Jeff,
#
#  I need to see the site plan for Burnet.  Remember I must get written
# approval from Brenda Key Stone before I can sell this property and she has
# concerns about the way the property will be subdivided.    I would also like
# to review the closing statements as soon as possible.
#
# Phillip
# --------------------------------------------------
# Email 30:
# --------------------------------------------------
# Lucy,
#
# I want to have an accurate rent roll as soon as possible. I faxed you a copy
# of this file.  You can fill in on the computer or just write in the correct
# amounts and I will input.
#
# --------------------------------------------------
# Email 31:
# --------------------------------------------------
# Brenda,
#
#  I checked my records and I mailed check #1178 for the normal amount on
# August 28th.  I mailed it to 4303 Pate Rd. #29, College Station, TX 77845.  I
# will go ahead and mail you another check.  If the first one shows up you can
# treat the 2nd as payment for October.
#
#  I know your concerns about the site plan.  I will not proceed without
# getting the details and getting your approval.
#
#  I will find that amortization schedule and send it soon.
#
# Phillip
# --------------------------------------------------
# Email 32:
# --------------------------------------------------
# Lucy,
#
#
# You wrote fewer checks this month.  Spent more money on Materials and less on
# Labor.
#
#
#    June  July  August
#
# Total Materials  2929  4085  4801
#
# Services  53  581  464
#
# Labor   3187  3428  2770
#
#
#
#
#
#
# Here are my questions on the August bank statement (attached):
#
# 1.  Check 1406  Walmart    Description and unit?
#
# 2.  Check 1410  Crumps     Detail description and unit?
#
# 3.  Check 1411  Lucy      What is this?
#
# 4.  Check 1415  Papes      Detail description and units?
#
# 5.  Checks 1416, 1417, and 1425  Why overtime?
#
# 6.  Check 1428    Ralph's   What unit?
#
# 7.  Check 1438    Walmart?    Description and unit?
#
#
# Try and pull together the support for these items and get back to me.
#
# Phillip
# --------------------------------------------------
# Email 33:
# --------------------------------------------------
# http://www.hearme.com/vc2/?chnlOwnr=pallen@enron.com
# --------------------------------------------------
# Email 34:
# --------------------------------------------------
# Jeff,
#
#  I received the rent roll.  I am going to be in San Marcos this weekend but I
# am booked with stage coach.  I will drive by Friday evening.
#  I will let you know next week if I need to see the inside.  Can you find out
# when Chelsea Villa last changed hands and for what price?
#
#  What about getting a look at the site plans for the Burnet deal.  Remember
# we have to get Brenda happy.
#
# Phillip
# --------------------------------------------------
# Email 35:
# --------------------------------------------------
#   9/8  9/7  diff
#
# Socal  36,600  37,200  -600
#
# NWPL  -51,000  -51,250  250
#
# San Juan -32,500  -32,000  -500
#
#
# The reason the benchmark report shows net selling San Juan is that the
# transport positions were rolled in on 9/8.  This added 800 shorts to San Juan
# and 200 longs to Socal.  Before this adjustment we bought 300 San Juan and
# sold 800 Socal.
#
# --------------------------------------------------
# Email 36:
# --------------------------------------------------
# why is aeco basis so low on the list?  Is NWPL mapped differently than AECO?
# What about the correlation to Nymex on AECO?
# --------------------------------------------------
# Email 37:
# --------------------------------------------------
# Jeff,
#
#  You would clearly receive a commission on a deal on the sagewood.
#
#   I am surprised by your request for payment on any type of project in which
# I might become involved with Creekside.  Are you in the business of brokering
# properties or contacts?  Is your position based on a legal or what you
# perceive to be an ethical issue?  Did you propose we look at developing a
# project from scratch?
#
#  I am not prepared to pay more than 2.7 for sagewood yet.
#
# Phillip
# --------------------------------------------------
# Email 38:
# --------------------------------------------------
# Larry,
#
#  Just a note to touch base on the sagewood townhomes and other development
# opportunities.
#
#  I stumbled across some other duplexes for sale on the same street. that were
# built by Reagan Lehmann.  22 Units were sold for
#  around $2 million. ($182,000/duplex).  I spoke to Reagan and he indicated
# that he had more units under construction that would be
#  available in the 180's.  Are the units he is selling significantly different
# from yours?  He mentioned some of the units are the 1308 floor
#  plan.  My bid of 2.7 million is almost $193,000/duplex.
#
#  As far as being an investor in a new project, I am still very interested.
#
#  Call or email with your thoughts.
#
# Phillip
# --------------------------------------------------
# Email 39:
# --------------------------------------------------
# Ina,
#
#  I scheduled a meeting with Jean Mrha tomorrow at 3:30
# --------------------------------------------------
# Email 40:
# --------------------------------------------------
# resumes of whom?
# --------------------------------------------------
# Email 41:
# --------------------------------------------------
# Richard,
#
#  Compare your california production to the numbers in the 2000 California Gas
# Report.  It shows 410.  But again that might be just what the two utilities
# receive.
# --------------------------------------------------
# Email 42:
# --------------------------------------------------
# Cooper,
#
#  Can you give access to the new west power site to Jay Reitmeyer.  He is an
# analyst in our group.
#
# Phillip
# --------------------------------------------------
# Email 43:
# --------------------------------------------------
# John Lavorato-M
#
# Mike Grigsby-D
# Keith Holst-D
# Frank Ermis-D
# Steve South-D
# Janie Tholt-D
#
# Scott Neal-P
# Hunter Shively-P
# Tom Martin-P
# John Arnold-P
# --------------------------------------------------
# Email 44:
# --------------------------------------------------
# Greg,
#
#  Got your message.  Good luck on the bike ride.
#
#  What were you doing to your apartment?  Are you setting up a studio?
#
#  The kids are back in school.  Otherwise just work is going on here.
#
# Keith
# --------------------------------------------------
# Email 45:
# --------------------------------------------------
# Why are his requests coming to me?
# --------------------------------------------------
# Email 46:
# --------------------------------------------------
# Mark,
#
#  Here is a spreadsheet detailing our September Socal trades. (I did not
# distinguish between buys vs. sells.)
#
#
#
# Phillip
# --------------------------------------------------
# Email 47:
# --------------------------------------------------
# Mark,
#
#  Were you able to log in to enron online and find socal today?
#
#  I will follow up with a list of our physical deals done yesterday and today.
#
# Phillip
# --------------------------------------------------
# Email 48:
# --------------------------------------------------
# Brenda
#
#  Can you send me your address in College Station.
#
# Phillip
# --------------------------------------------------
# Email 49:
# --------------------------------------------------
# Mark,
#
#  The following is a guest password that will allow you temporary view only
# access to EnronOnline.  Please note, the user ID and password are CASE
# SENSITIVE.
#
# Guest User ID:  GNA45925
# Guest Password: YJ53KU42
#
# Log in to www.enrononline.com and install shockwave using instructions
# below.  I have set up a composite page with western basis and cash prices to
# help you filter through the products.  The title of the composite page is
# Mark's Page.  If you have any problems logging in you can call me at
# (713)853-7041 or Kathy Moore, EnronOnline HelpDesk, 713/853-HELP (4357).
#
#
# The Shockwave installer can be found within "About EnronOnline" on the home
# page.  After opening "About EnronOnline", using right scroll bar, go to the
# bottom.  Click on "download Shockwave" and follow the directions.  After
# loading Shockwave, shut down and reopen browser (i.e. Microsoft Internet
# Explorer/Netscape).
#
# I hope you will find this site useful.
#
#
# Sincerely,
#
# Phillip Allen
#
#
# --------------------------------------------------
# Email 50:
# --------------------------------------------------
# Mark,
#
#  Attached is a spreadsheet that lists the end of day midmarkets for socal
# basis and socal/san juan spreads.  I listed the days during bidweek that
# reflected financial trading for Socal Index and the actual gas daily prints
# before and after bidweek.
#
#
#
#
#
#
#
#
#  The following observations can be made:
#
#   July 1.  The basis market  anticipated a Socal/San Juan spread of .81 vs
# actual of .79
#    2.  Perceived index was 4.95 vs actual of 4.91
#    3.  Socal Gas Daily Swaps are trading at a significant premium.
#
#   Aug. 1.  The basis market  anticipated a Socal/San Juan spread of 1.04 vs
# actual of .99
#    2.  Perceived index was 4.54 vs actual of 4.49
#    3.  Gas daily spreads were much wider before and after bidweek than the
# monthly postings
#    4.  Socal Gas Daily Swaps are trading at a significant premium.
#
#
#
#  Enron Online will allow you to monitor the value of financial swaps against
# the index, as well as, spreads to other locations.  Please call with any
# questions.
#
# Phillip
#
#
#
# --------------------------------------------------

# %%
filtered_df = filtered_df[filtered_df['content'].str.count(' ') > 2]
filtered_df = filtered_df[~filtered_df['content'].str.contains('From:', case=False, na=False) & 
                                    ~filtered_df['content'].str.contains('To:', case=False, na=False) &
                                    ~filtered_df['content'].str.contains('Message from:', case=False, na=False) ]
# remove the rows if the size of content is more than 1000
filtered_df = filtered_df[filtered_df['content'].str.len() < 1000]
# remove rows if the from email is also present in to email or to email is null
filtered_df = filtered_df[~filtered_df['To'].isnull()]

print(f"Total rows: {len(filtered_df)}")
for i in range(50):
    # print the content of the first 50 emails
    print(f"Email {i+1}:")
    print("--------------------------------------------------")
    print(filtered_df.iloc[i]['content'])
    print("--------------------------------------------------")
# Out:
# Total rows: 192690
# Email 1:
# --------------------------------------------------
# Here is our forecast
#
#
# --------------------------------------------------
# Email 2:
# --------------------------------------------------
# Traveling to have a business meeting takes the fun out of the trip.  Especially if you have to prepare a presentation.  I would suggest holding the business plan meetings here then take a trip without any formal business meetings.  I would even try and get some honest opinions on whether a trip is even desired or necessary.
#
# As far as the business meetings, I think it would be more productive to try and stimulate discussions across the different groups about what is working and what is not.  Too often the presenter speaks and the others are quiet just waiting for their turn.   The meetings might be better if held in a round table discussion format.
#
# My suggestion for where to go is Austin.  Play golf and rent a ski boat and jet ski's.  Flying somewhere takes too much time.
#
# --------------------------------------------------
# Email 3:
# --------------------------------------------------
# test successful.  way to go!!!
# --------------------------------------------------
# Email 4:
# --------------------------------------------------
# Randy,
#
#  Can you send me a schedule of the salary and level of everyone in the
# scheduling group.  Plus your thoughts on any changes that need to be made.
# (Patti S for example)
#
# Phillip
# --------------------------------------------------
# Email 5:
# --------------------------------------------------
# Let's shoot for Tuesday at 11:45.
# --------------------------------------------------
# Email 6:
# --------------------------------------------------
# Greg,
#
#  How about either next Tuesday or Thursday?
#
# Phillip
# --------------------------------------------------
# Email 7:
# --------------------------------------------------
# Please cc the following distribution list with updates:
#
# Phillip Allen (pallen@enron.com)
# Mike Grigsby (mike.grigsby@enron.com)
# Keith Holst (kholst@enron.com)
# Monique Sanchez
# Frank Ermis
# John Lavorato
#
#
# Thank you for your help
#
# Phillip Allen
#
# --------------------------------------------------
# Email 8:
# --------------------------------------------------
# any morning between 10 and 11:30
# --------------------------------------------------
# Email 9:
# --------------------------------------------------
# 1. login:  pallen pw: ke9davis
#
#  I don't think these are required by the ISP
#
#   2.  static IP address
#
#  IP: 64.216.90.105
#  Sub: 255.255.255.248
#  gate: 64.216.90.110
#  DNS: 151.164.1.8
#
#   3.  Company: 0413
#         RC:  105891
# --------------------------------------------------
# Email 10:
# --------------------------------------------------
# Mr. Buckner,
#
#  For delivered gas behind San Diego, Enron Energy Services is the appropriate
# Enron entity.  I have forwarded your request to Zarin Imam at EES.  Her phone
# number is 713-853-7107.
#
# Phillip Allen
# --------------------------------------------------
# Email 11:
# --------------------------------------------------
# Lucy,
#
#  Here are the rentrolls:
#
#
#
#  Open them and save in the rentroll folder.  Follow these steps so you don't
# misplace these files.
#
#  1.  Click on Save As
#  2.  Click on the drop down triangle under Save in:
#  3.  Click on the  (C): drive
#  4.  Click on the appropriate folder
#  5.  Click on Save:
#
# Phillip
# --------------------------------------------------
# Email 12:
# --------------------------------------------------
# Dave,
#
#  Here are the names of the west desk members by category.  The origination
# side is very sparse.
#
#
#
#
#
# Phillip
#
# --------------------------------------------------
# Email 13:
# --------------------------------------------------
# Paula,
#
#  35 million is fine
#
# Phillip
# --------------------------------------------------
# Email 14:
# --------------------------------------------------
# Tim,
#
# mike grigsby is having problems with accessing the west power site.  Can you please make sure he has an active password.
#
# Thank you,
#
# Phillip
# --------------------------------------------------
# Email 15:
# --------------------------------------------------
# Brenda,
#
# Please use the second check as the October payment.  If you have already
# tossed it, let me know so I can mail you another.
#
# Phillip
# --------------------------------------------------
# Email 16:
# --------------------------------------------------
# I think Fletch has a good CPA.  I am still doing my own.
# --------------------------------------------------
# Email 17:
# --------------------------------------------------
# Brenda,
#
#  Please use the second check as my October payment.  I have my copy of the
# original deal.  Do you want me to fax this to you?
#
# Phillip
# --------------------------------------------------
# Email 18:
# --------------------------------------------------
# Reagan,
#
# Just wanted to give you an update.  I have changed the unit mix to include some 1 bedrooms and reduced the number of buildings to 12.  Kipp Flores is working on the construction drawings.  At the same time I am pursuing FHA financing.  Once the construction drawings are complete I will send them to you for a revised bid.  Your original bid was competitive and I am still attracted to your firm because of your strong local presence and contacts.
#
# Phillip
# --------------------------------------------------
# Email 19:
# --------------------------------------------------
# Nymex expiration is during this time frame.  Please reschedule.
# --------------------------------------------------
# Email 20:
# --------------------------------------------------
# Chris,
#
#  What is the latest with PG&E?  We have been having good discussions
# regarding EOL.
#  Call me when you can. X37041
#
# Phillip
# --------------------------------------------------
# Email 21:
# --------------------------------------------------
# Greg,
#
# Happy B-day. Email me your phone # and I will call you.
#
# Keith
# --------------------------------------------------
# Email 22:
# --------------------------------------------------
# Kathy,
#
# Regarding the guest password for gas daily, can you please relay the
# information to Mike Grigsby at 37031 so he can pass it along to the user at
# gas daily today.  I will be out of the office on Friday.
#
# thank you
#
# Phillip
# --------------------------------------------------
# Email 23:
# --------------------------------------------------
# John,
#
#  Denver's short rockies position  beyond 2002 is created by their Trailblazer
# transport.  They are unhedged 15,000/d in 2003 and 25,000/d in 2004 and
# 2005.
#
#  They are scrubbing all their books and booking the Hubert deal on Wednesday
# and Thursday.
#
# Phillip
# --------------------------------------------------
# Email 24:
# --------------------------------------------------
# Jim,
#
# Is there going to be a conference call or some type of weekly meeting about all the regulatory issues facing California this week?  Can you make sure the gas desk is included.
#
# Phillip
# --------------------------------------------------
# Email 25:
# --------------------------------------------------
# George,
#
#  Here sales numbers from Reagan:
#
#
#
#
#  As you can see his units sold at a variety of prices per square foot.  The
# 1308/1308 model seems to have the most data and looks most similiar to the
# units you are selling.  At  2.7 MM, my bid is .70/sf higher than his units
# under construction.  I am having a hard time justifying paying much more with
# competition on the way.  The price I am bidding is higher than any deals
# actually done to date.
#
#  Let me know what you think.  I will follow up with an email and phone call
# about Cherry Creek.  I am sure Deborah Yates let you know that the bid was
# rejected on the De Ville property.
#
# Phillip Allen
#
#
#
#
#
#
#
# --------------------------------------------------
# Email 26:
# --------------------------------------------------
# Jeff,
#
#  What is up with Burnet?
#
# Phillip
# --------------------------------------------------
# Email 27:
# --------------------------------------------------
# Jeff,
#
#  I need to see the site plan for Burnet.  Remember I must get written
# approval from Brenda Key Stone before I can sell this property and she has
# concerns about the way the property will be subdivided.    I would also like
# to review the closing statements as soon as possible.
#
# Phillip
# --------------------------------------------------
# Email 28:
# --------------------------------------------------
# Lucy,
#
# I want to have an accurate rent roll as soon as possible. I faxed you a copy
# of this file.  You can fill in on the computer or just write in the correct
# amounts and I will input.
#
# --------------------------------------------------
# Email 29:
# --------------------------------------------------
# Brenda,
#
#  I checked my records and I mailed check #1178 for the normal amount on
# August 28th.  I mailed it to 4303 Pate Rd. #29, College Station, TX 77845.  I
# will go ahead and mail you another check.  If the first one shows up you can
# treat the 2nd as payment for October.
#
#  I know your concerns about the site plan.  I will not proceed without
# getting the details and getting your approval.
#
#  I will find that amortization schedule and send it soon.
#
# Phillip
# --------------------------------------------------
# Email 30:
# --------------------------------------------------
# Lucy,
#
#
# You wrote fewer checks this month.  Spent more money on Materials and less on
# Labor.
#
#
#    June  July  August
#
# Total Materials  2929  4085  4801
#
# Services  53  581  464
#
# Labor   3187  3428  2770
#
#
#
#
#
#
# Here are my questions on the August bank statement (attached):
#
# 1.  Check 1406  Walmart    Description and unit?
#
# 2.  Check 1410  Crumps     Detail description and unit?
#
# 3.  Check 1411  Lucy      What is this?
#
# 4.  Check 1415  Papes      Detail description and units?
#
# 5.  Checks 1416, 1417, and 1425  Why overtime?
#
# 6.  Check 1428    Ralph's   What unit?
#
# 7.  Check 1438    Walmart?    Description and unit?
#
#
# Try and pull together the support for these items and get back to me.
#
# Phillip
# --------------------------------------------------
# Email 31:
# --------------------------------------------------
# Jeff,
#
#  I received the rent roll.  I am going to be in San Marcos this weekend but I
# am booked with stage coach.  I will drive by Friday evening.
#  I will let you know next week if I need to see the inside.  Can you find out
# when Chelsea Villa last changed hands and for what price?
#
#  What about getting a look at the site plans for the Burnet deal.  Remember
# we have to get Brenda happy.
#
# Phillip
# --------------------------------------------------
# Email 32:
# --------------------------------------------------
#   9/8  9/7  diff
#
# Socal  36,600  37,200  -600
#
# NWPL  -51,000  -51,250  250
#
# San Juan -32,500  -32,000  -500
#
#
# The reason the benchmark report shows net selling San Juan is that the
# transport positions were rolled in on 9/8.  This added 800 shorts to San Juan
# and 200 longs to Socal.  Before this adjustment we bought 300 San Juan and
# sold 800 Socal.
#
# --------------------------------------------------
# Email 33:
# --------------------------------------------------
# why is aeco basis so low on the list?  Is NWPL mapped differently than AECO?
# What about the correlation to Nymex on AECO?
# --------------------------------------------------
# Email 34:
# --------------------------------------------------
# Jeff,
#
#  You would clearly receive a commission on a deal on the sagewood.
#
#   I am surprised by your request for payment on any type of project in which
# I might become involved with Creekside.  Are you in the business of brokering
# properties or contacts?  Is your position based on a legal or what you
# perceive to be an ethical issue?  Did you propose we look at developing a
# project from scratch?
#
#  I am not prepared to pay more than 2.7 for sagewood yet.
#
# Phillip
# --------------------------------------------------
# Email 35:
# --------------------------------------------------
# Larry,
#
#  Just a note to touch base on the sagewood townhomes and other development
# opportunities.
#
#  I stumbled across some other duplexes for sale on the same street. that were
# built by Reagan Lehmann.  22 Units were sold for
#  around $2 million. ($182,000/duplex).  I spoke to Reagan and he indicated
# that he had more units under construction that would be
#  available in the 180's.  Are the units he is selling significantly different
# from yours?  He mentioned some of the units are the 1308 floor
#  plan.  My bid of 2.7 million is almost $193,000/duplex.
#
#  As far as being an investor in a new project, I am still very interested.
#
#  Call or email with your thoughts.
#
# Phillip
# --------------------------------------------------
# Email 36:
# --------------------------------------------------
# Ina,
#
#  I scheduled a meeting with Jean Mrha tomorrow at 3:30
# --------------------------------------------------
# Email 37:
# --------------------------------------------------
# Richard,
#
#  Compare your california production to the numbers in the 2000 California Gas
# Report.  It shows 410.  But again that might be just what the two utilities
# receive.
# --------------------------------------------------
# Email 38:
# --------------------------------------------------
# Cooper,
#
#  Can you give access to the new west power site to Jay Reitmeyer.  He is an
# analyst in our group.
#
# Phillip
# --------------------------------------------------
# Email 39:
# --------------------------------------------------
# John Lavorato-M
#
# Mike Grigsby-D
# Keith Holst-D
# Frank Ermis-D
# Steve South-D
# Janie Tholt-D
#
# Scott Neal-P
# Hunter Shively-P
# Tom Martin-P
# John Arnold-P
# --------------------------------------------------
# Email 40:
# --------------------------------------------------
# Greg,
#
#  Got your message.  Good luck on the bike ride.
#
#  What were you doing to your apartment?  Are you setting up a studio?
#
#  The kids are back in school.  Otherwise just work is going on here.
#
# Keith
# --------------------------------------------------
# Email 41:
# --------------------------------------------------
# Why are his requests coming to me?
# --------------------------------------------------
# Email 42:
# --------------------------------------------------
# Mark,
#
#  Here is a spreadsheet detailing our September Socal trades. (I did not
# distinguish between buys vs. sells.)
#
#
#
# Phillip
# --------------------------------------------------
# Email 43:
# --------------------------------------------------
# Mark,
#
#  Were you able to log in to enron online and find socal today?
#
#  I will follow up with a list of our physical deals done yesterday and today.
#
# Phillip
# --------------------------------------------------
# Email 44:
# --------------------------------------------------
# Brenda
#
#  Can you send me your address in College Station.
#
# Phillip
# --------------------------------------------------
# Email 45:
# --------------------------------------------------
# Mark,
#
#  The following is a guest password that will allow you temporary view only
# access to EnronOnline.  Please note, the user ID and password are CASE
# SENSITIVE.
#
# Guest User ID:  GNA45925
# Guest Password: YJ53KU42
#
# Log in to www.enrononline.com and install shockwave using instructions
# below.  I have set up a composite page with western basis and cash prices to
# help you filter through the products.  The title of the composite page is
# Mark's Page.  If you have any problems logging in you can call me at
# (713)853-7041 or Kathy Moore, EnronOnline HelpDesk, 713/853-HELP (4357).
#
#
# The Shockwave installer can be found within "About EnronOnline" on the home
# page.  After opening "About EnronOnline", using right scroll bar, go to the
# bottom.  Click on "download Shockwave" and follow the directions.  After
# loading Shockwave, shut down and reopen browser (i.e. Microsoft Internet
# Explorer/Netscape).
#
# I hope you will find this site useful.
#
#
# Sincerely,
#
# Phillip Allen
#
#
# --------------------------------------------------
# Email 46:
# --------------------------------------------------
# Alan,
#
# You should have received updated numbers from Keith Holst.  Call me if you did not receive them.
#
# Phillip
# --------------------------------------------------
# Email 47:
# --------------------------------------------------
# Suzanne,
#
#  Can you give me more details or email  the plan prior to meeting?  What do I
# need to provide besides headcount?
#  Otherwise any afternoon next week would be fine
#
# Phillip
# --------------------------------------------------
# Email 48:
# --------------------------------------------------
# Colleen,
#
#  Please add Mike Grigsby to the distribution.
#
#  On another note, do you have any idea how Patti is holding up?
#
# Phillip
# --------------------------------------------------
# Email 49:
# --------------------------------------------------
# Brad,
#
#  With regard to Tori Kuykendall, I would like to promote her to commercial
# manager instead of converting her from a commercial support manager to an
# associate.  Her duties since the beginning of the year have been those of a
# commercial manager.  I have no doubt that she will compare favorably to
# others in that category at year end.
#
#  Martin Cuilla on the central desk is in a similiar situation as Tori.
# Hunter would like Martin handled the same as Tori.
#
#  Let me know if there are any issues.
#
# Phillip
# --------------------------------------------------
# Email 50:
# --------------------------------------------------
# Bruce,
#
# Can you stop by and set up my reuters.
#
# Phillip
# --------------------------------------------------

# %%
sample_emails = filtered_df.sample(n=25000, random_state=42)  # Use random_state for reproducibility
sample_emails['Cc'] = sample_emails['Cc'].replace(["", None], "None")

# Save to CSV
sample_emails.to_csv(sample_dataset, index=False)

print("Sample emails saved to sample_emails.csv")
# Out:
# Sample emails saved to sample_emails.csv

# %%
sample_emails.head(50)
# Out:
#                                                   message  \
# 86994   Message-ID: <31664984.1075852142386.JavaMail.e...
# 144846  Message-ID: <5115047.1075855610475.JavaMail.ev...
# 427691  Message-ID: <12042696.1075844566306.JavaMail.e...
# 322555  Message-ID: <17502456.1075846133538.JavaMail.e...
# 81652   Message-ID: <8313323.1075843861667.JavaMail.ev...
# 325128  Message-ID: <30868936.1075852949613.JavaMail.e...
# 216804  Message-ID: <23840170.1075856432272.JavaMail.e...
# 384495  Message-ID: <21558926.1075859514971.JavaMail.e...
# 468495  Message-ID: <11681742.1075841766782.JavaMail.e...
# 510349  Message-ID: <4890830.1075839946930.JavaMail.ev...
# 75218   Message-ID: <31699425.1075843684724.JavaMail.e...
# 481488  Message-ID: <5196046.1075860038482.JavaMail.ev...
# 285894  Message-ID: <24224257.1075844042474.JavaMail.e...
# 266597  Message-ID: <21942045.1075857687507.JavaMail.e...
# 169556  Message-ID: <16943882.1075849683480.JavaMail.e...
# 360145  Message-ID: <526198.1075842309527.JavaMail.eva...
# 405590  Message-ID: <30513088.1075846658302.JavaMail.e...
# 389359  Message-ID: <25285550.1075853436354.JavaMail.e...
# 347314  Message-ID: <26627287.1075842786121.JavaMail.e...
# 362312  Message-ID: <17224147.1075842420931.JavaMail.e...
# 288446  Message-ID: <3230853.1075855002545.JavaMail.ev...
# 76606   Message-ID: <3545726.1075843727723.JavaMail.ev...
# 309191  Message-ID: <19335125.1075845727469.JavaMail.e...
# 448337  Message-ID: <2136089.1075841567705.JavaMail.ev...
# 32931   Message-ID: <20281433.1075863728608.JavaMail.e...
# 370830  Message-ID: <6349318.1075858650424.JavaMail.ev...
# 434797  Message-ID: <12936630.1075851975799.JavaMail.e...
# 311527  Message-ID: <31286280.1075845793494.JavaMail.e...
# 439932  Message-ID: <5613322.1075844268946.JavaMail.ev...
# 348576  Message-ID: <29444938.1075858578780.JavaMail.e...
# 102561  Message-ID: <9187269.1075854196096.JavaMail.ev...
# 89430   Message-ID: <3696046.1075854436525.JavaMail.ev...
# 286405  Message-ID: <23777751.1075844055315.JavaMail.e...
# 62778   Message-ID: <1425900.1075843022361.JavaMail.ev...
# 422459  Message-ID: <13640367.1075844782014.JavaMail.e...
# 188656  Message-ID: <11843461.1075855434400.JavaMail.e...
# 153297  Message-ID: <30617081.1075845010562.JavaMail.e...
# 374477  Message-ID: <17696625.1075858366914.JavaMail.e...
# 287994  Message-ID: <32609167.1075844085259.JavaMail.e...
# 366995  Message-ID: <9062361.1075841449035.JavaMail.ev...
# 260651  Message-ID: <20264079.1075840803215.JavaMail.e...
# 410840  Message-ID: <29725787.1075846722925.JavaMail.e...
# 155818  Message-ID: <4344641.1075845043386.JavaMail.ev...
# 84297   Message-ID: <20345085.1075853934273.JavaMail.e...
# 173094  Message-ID: <15025429.1075844950754.JavaMail.e...
# 2907    Message-ID: <30515713.1075855680847.JavaMail.e...
# 318559  Message-ID: <10057904.1075845954458.JavaMail.e...
# 9821    Message-ID: <27672066.1075862385422.JavaMail.e...
# 99200   Message-ID: <23524557.1075855486721.JavaMail.e...
# 469923  Message-ID: <12196095.1075841859826.JavaMail.e...
#
#                                                   content  \
# 86994   I believe all the bugs have been worked out of...
# 144846  Yahoo! News\tEdit Breaking News Alerts - Yahoo...
# 427691  Are you still working every other day?  Please...
# 322555  Kay -\n\nI've reached a verbal agreement with ...
# 81652   This copy should correct all of the the typos ...
# 325128  The report named: NG - PROPT P/L <http://trv.c...
# 216804  Hi everyone.\n\nPlease rsvp to me by tomorrow ...
# 384495  I have been asked by numerous parties to put t...
# 468495  Deal # 460860 is entered as flowing every day ...
# 510349  We are 7 MW long all hours at Montana System, ...
# 75218   Robert --\n\nPls take a look.  We have some ne...
# 481488  Ken Lay and Jeff Skilling were interviewed on ...
# 285894  Take a look at the California send out numbers...
# 266597  Hickerson always claims that they have var by ...
# 169556  Want a NEW high speed computer?\n\n866 MHz Pen...
# 360145  Ken Lay and Jeff Skilling were interviewed on ...
# 405590  Can we keep the upside -- I believe the answer...
# 389359  Don't go without me ... I can't go this week  ...
# 347314  Dear Mr. Koelemay:\n\nAt the request of Mark W...
# 362312  My RSVP for June Lunch.\n\nThanks\n\nDebra Per...
# 288446  Attached is the information on the May 2002 Ch...
# 76606   Attached is a set of draft talking points for ...
# 309191  Herman,\n\nAttached is a revised form of Memor...
# 448337  \n\nStart Date: 1/27/02; HourAhead hour: 22;  ...
# 32931   \n \nAttached are the two files for this week'...
# 370830  Nichole,\n\nThe payment information for the Pe...
# 434797  The attached reflect the comments that I recei...
# 311527  The tax representation which should be include...
# 439932  Attached for filing in docket V010003 are Enro...
# 348576  \nShould have sent you this version:\n\nSteph\...
# 102561  (See attached file: HPLN0307.xls)\n\n - HPLN03...
# 89430   Guys, gas with a $5.00 handle is not a good th...
# 286405            It's almost time to check your pulse...
# 62778   Attached please find the updated state matrix....
# 422459  Hi Stephanie, I will get the final version of ...
# 188656  \nYou have been on my mind..How are things in ...
# 153297                                     Thanks.   Mark
# 374477  Could you please ensure that these books are s...
# 287994  Please make note of the following important ch...
# 366995  here are the deltas, let me know if you have a...
# 260651  Credit \nBill may want to do a contract for Sa...
# 410840  Part I:  Dress Code for Female FERC Lawyers at...
# 155818  Thanks for the comments.  I will make sure Tan...
# 84297   Dana,\n\nThis is Marylyn's phone number 713-68...
# 173094  Stan,\n\nHaving circulated the attached meetin...
# 2907    Jed,\n\n I understand you have been contacted ...
# 318559  I'll be calling in from out of the office, as ...
# 9821    \nDan,\n\nJust wanted to wish you, Jane, Jorda...
# 99200   Employees who ride Metro bus routes 214 and 21...
# 469923  Kate, could you help us on deal #595155.1 that...
#
#                                           Message-ID  \
# 86994   <31664984.1075852142386.JavaMail.evans@thyme
# 144846   <5115047.1075855610475.JavaMail.evans@thyme
# 427691  <12042696.1075844566306.JavaMail.evans@thyme
# 322555  <17502456.1075846133538.JavaMail.evans@thyme
# 81652    <8313323.1075843861667.JavaMail.evans@thyme
# 325128  <30868936.1075852949613.JavaMail.evans@thyme
# 216804  <23840170.1075856432272.JavaMail.evans@thyme
# 384495  <21558926.1075859514971.JavaMail.evans@thyme
# 468495  <11681742.1075841766782.JavaMail.evans@thyme
# 510349   <4890830.1075839946930.JavaMail.evans@thyme
# 75218   <31699425.1075843684724.JavaMail.evans@thyme
# 481488   <5196046.1075860038482.JavaMail.evans@thyme
# 285894  <24224257.1075844042474.JavaMail.evans@thyme
# 266597  <21942045.1075857687507.JavaMail.evans@thyme
# 169556  <16943882.1075849683480.JavaMail.evans@thyme
# 360145    <526198.1075842309527.JavaMail.evans@thyme
# 405590  <30513088.1075846658302.JavaMail.evans@thyme
# 389359  <25285550.1075853436354.JavaMail.evans@thyme
# 347314  <26627287.1075842786121.JavaMail.evans@thyme
# 362312  <17224147.1075842420931.JavaMail.evans@thyme
# 288446   <3230853.1075855002545.JavaMail.evans@thyme
# 76606    <3545726.1075843727723.JavaMail.evans@thyme
# 309191  <19335125.1075845727469.JavaMail.evans@thyme
# 448337   <2136089.1075841567705.JavaMail.evans@thyme
# 32931   <20281433.1075863728608.JavaMail.evans@thyme
# 370830   <6349318.1075858650424.JavaMail.evans@thyme
# 434797  <12936630.1075851975799.JavaMail.evans@thyme
# 311527  <31286280.1075845793494.JavaMail.evans@thyme
# 439932   <5613322.1075844268946.JavaMail.evans@thyme
# 348576  <29444938.1075858578780.JavaMail.evans@thyme
# 102561   <9187269.1075854196096.JavaMail.evans@thyme
# 89430    <3696046.1075854436525.JavaMail.evans@thyme
# 286405  <23777751.1075844055315.JavaMail.evans@thyme
# 62778    <1425900.1075843022361.JavaMail.evans@thyme
# 422459  <13640367.1075844782014.JavaMail.evans@thyme
# 188656  <11843461.1075855434400.JavaMail.evans@thyme
# 153297  <30617081.1075845010562.JavaMail.evans@thyme
# 374477  <17696625.1075858366914.JavaMail.evans@thyme
# 287994  <32609167.1075844085259.JavaMail.evans@thyme
# 366995   <9062361.1075841449035.JavaMail.evans@thyme
# 260651  <20264079.1075840803215.JavaMail.evans@thyme
# 410840  <29725787.1075846722925.JavaMail.evans@thyme
# 155818   <4344641.1075845043386.JavaMail.evans@thyme
# 84297   <20345085.1075853934273.JavaMail.evans@thyme
# 173094  <15025429.1075844950754.JavaMail.evans@thyme
# 2907    <30515713.1075855680847.JavaMail.evans@thyme
# 318559  <10057904.1075845954458.JavaMail.evans@thyme
# 9821    <27672066.1075862385422.JavaMail.evans@thyme
# 99200   <23524557.1075855486721.JavaMail.evans@thyme
# 469923  <12196095.1075841859826.JavaMail.evans@thyme
#
#                                         Date  \
# 86994   Wed, 17 Oct 2001 10:19:20 -0700 (PDT
# 144846   Fri, 4 May 2001 23:13:00 -0700 (PDT
# 427691  Mon, 11 Sep 2000 06:22:00 -0700 (PDT
# 322555   Thu, 9 Nov 2000 10:05:00 -0800 (PST
# 81652    Wed, 7 Mar 2001 11:11:00 -0800 (PST
# 325128  Fri, 19 Oct 2001 14:46:23 -0700 (PDT
# 216804   Thu, 3 May 2001 02:39:00 -0700 (PDT
# 384495  Thu, 20 Jan 2000 09:16:00 -0800 (PST
# 468495  Thu, 16 Nov 2000 05:49:00 -0800 (PST
# 510349   Fri, 1 Jun 2001 16:41:44 -0700 (PDT
# 75218   Thu, 26 Apr 2001 17:19:00 -0700 (PDT
# 481488  Wed, 13 Dec 2000 06:34:00 -0800 (PST
# 285894  Thu, 16 Nov 2000 04:46:00 -0800 (PST
# 266597  Sun, 10 Dec 2000 20:17:00 -0800 (PST
# 169556  Thu, 15 Feb 2001 12:42:00 -0800 (PST
# 360145  Wed, 13 Dec 2000 06:34:00 -0800 (PST
# 405590  Thu, 17 Feb 2000 05:06:00 -0800 (PST
# 389359  Tue, 26 Sep 2000 08:02:00 -0700 (PDT
# 347314  Wed, 18 Apr 2001 04:53:00 -0700 (PDT
# 362312   Mon, 4 Jun 2001 03:20:00 -0700 (PDT
# 288446  Thu, 19 Jul 2001 07:53:00 -0700 (PDT
# 76606   Wed, 28 Feb 2001 09:04:00 -0800 (PST
# 309191  Fri, 25 May 2001 03:54:00 -0700 (PDT
# 448337  Sun, 27 Jan 2002 19:37:31 -0800 (PST
# 32931   Tue, 21 Aug 2001 09:47:58 -0700 (PDT
# 370830  Wed, 17 Oct 2001 09:11:20 -0700 (PDT
# 434797  Wed, 18 Jul 2001 11:09:00 -0700 (PDT
# 311527   Thu, 7 Dec 2000 02:08:00 -0800 (PST
# 439932   Tue, 3 Apr 2001 08:40:00 -0700 (PDT
# 348576  Wed, 18 Jul 2001 14:18:36 -0700 (PDT
# 102561   Tue, 6 Mar 2001 02:40:00 -0800 (PST
# 89430    Wed, 6 Sep 2000 10:12:00 -0700 (PDT
# 286405   Mon, 9 Oct 2000 11:26:00 -0700 (PDT
# 62778    Tue, 7 Nov 2000 06:28:00 -0800 (PST
# 422459   Tue, 3 Apr 2001 09:36:00 -0700 (PDT
# 188656   Tue, 4 Dec 2001 19:04:53 -0800 (PST
# 153297  Fri, 13 Oct 2000 11:09:00 -0700 (PDT
# 374477  Wed, 21 Jun 2000 16:45:00 -0700 (PDT
# 287994   Fri, 8 Dec 2000 08:57:00 -0800 (PST
# 366995   Mon, 3 Dec 2001 13:35:24 -0800 (PST
# 260651   Tue, 5 Feb 2002 14:05:40 -0800 (PST
# 410840   Thu, 9 Mar 2000 08:16:00 -0800 (PST
# 155818   Thu, 9 Dec 1999 00:44:00 -0800 (PST
# 84297   Fri, 14 Apr 2000 04:46:00 -0700 (PDT
# 173094  Thu, 25 May 2000 07:23:00 -0700 (PDT
# 2907    Mon, 23 Oct 2000 08:55:00 -0700 (PDT
# 318559  Tue, 14 Nov 2000 23:31:00 -0800 (PST
# 9821    Wed, 21 Nov 2001 10:45:23 -0800 (PST
# 99200   Fri, 10 Nov 2000 09:47:00 -0800 (PST
# 469923   Tue, 1 May 2001 05:27:00 -0700 (PDT
#
#                                     From  \
# 86994                kate.symes@enron.co
# 144846  alerts-breakingnews@yahoo-inc.co
# 427691          sara.shackleton@enron.co
# 322555           mitch.robinson@enron.co
# 81652             jeff.dasovich@enron.co
# 325128         errol.mclaughlin@enron.co
# 216804         shirley.crenshaw@enron.co
# 384495            stuart.zisman@enron.co
# 468495             sharen.cason@enron.co
# 510349           cara.semperger@enron.co
# 75218             james.steffes@enron.co
# 481488         public.relations@enron.co
# 285894          jeffery.fawcett@enron.co
# 266597            john.lavorato@enron.co
# 169556              clickathome@enron.co
# 360145         public.relations@enron.co
# 405590              susan.scott@enron.co
# 389359          elizabeth.sager@enron.co
# 347314        debra.perlingiere@enron.co
# 362312        debra.perlingiere@enron.co
# 288446               donna.teal@enron.co
# 76606             james.steffes@enron.co
# 309191        kathleen.carnahan@enron.co
# 448337               pete.davis@enron.co
# 32931                 rika.imai@enron.co
# 370830             richard.ring@enron.co
# 434797             rcarroll@bracepatt.co
# 311527         gkutzschbach@fulbright.co
# 439932             robert.frank@enron.co
# 348576         stephanie.miller@enron.co
# 102561                    mjones7@txu.co
# 89430            david.delainey@enron.co
# 286405      enron.announcements@enron.co
# 62778               margo.reyna@enron.co
# 422459            cheryl.nelson@enron.co
# 188656                   fergy4@attbi.co
# 153297            mark.haedicke@enron.co
# 374477           robin.rodrigue@enron.co
# 287994              sap.hotline@enron.co
# 366995            john.griffith@enron.co
# 260651              david.oxley@enron.co
# 410840              susan.scott@enron.co
# 155818            mark.haedicke@enron.co
# 84297                   choirmats@aol.co
# 173094                   mmcgrath@eei.or
# 2907              phillip.allen@enron.co
# 318559                 kay.mann@enron.co
# 9821               susan.bailey@enron.co
# 99200       enron.announcements@enron.co
# 469923              mark.confer@enron.co
#
#                                                        To  \
# 86994                          shift.dl-portland@enron.co
# 144846                              mike.grigsby@enron.co
# 427691                      michael.khajeh-noori@enron.co
# 322555                                  kay.mann@enron.co
# 81652                              jeff.dasovich@enron.co
# 325128  john.arnold@enron.com, bilal.bajwa@enron.com, ...
# 216804  vince.kaminski@enron.com, stinson.gibner@enron...
# 384495  elizabeth.sager@enron.com, greg.johnston@enron...
# 468495       kate.symes@enron.com, carla.hoffman@enron.co
# 510349                            shift.portland@enron.co
# 75218   robert.neusteadter@enron.com, jeff.dasovich@en...
# 481488                               all.houston@enron.co
# 285894      steven.harris@enron.com, kevin.hyatt@enron.co
# 266597                            vladimir.gorny@enron.co
# 169556                               clickathome@enron.co
# 360145                               all.houston@enron.co
# 405590   elizabeth.brown@enron.com, lindy.donoho@enron.co
# 389359                              barbara.gray@enron.co
# 347314                                  akoelemay@cogc.co
# 362312                                   gruyinc@flash.ne
# 288446                             georgi.landau@enron.co
# 76606   david.delainey@enron.com, steven.kean@enron.co...
# 309191                              herman.manis@enron.co
# 448337                                pete.davis@enron.co
# 32931   russell.ballato@enron.com, hicham.benjelloun@e...
# 370830                            nichole.gunter@enron.co
# 434797  linda.robertson3@att.net, dwatkiss@bracepatt.c...
# 311527  ben.f.jacoby@enron.com, kay.mann@enron.com, jk...
# 439932                           retailelectricity@ftc.go
# 348576                              gerald.nemec@enron.co
# 102561  daren.j.farmer@enron.com, ggreen2@txu.com, cst...
# 89430         jeff.donahue@enron.com, todd.busby@enron.co
# 286405                             all.worldwide@enron.co
# 62778   sue.nord@enron.com, scott.bolton@enron.com, ma...
# 422459  stephanie.panus@enron.com, sara.shackleton@enr...
# 188656                                tana.jones@enron.co
# 153297                               alan.larsen@enron.co
# 374477          virendra.patel@enron.com, wei.hu@enron.co
# 287994  isc.groups@enron.com, enron.users@enron.com, e...
# 366995                             dutch.quigley@enron.co
# 260651    louise.kitchen@enron.com, greg.whalley@enron.co
# 410840                                ahebert@akingump.co
# 155818                            louise.kitchen@enron.co
# 84297                                 dana.davis@enron.co
# 173094                            stanley.horton@enron.co
# 2907                                  jedglick@hotmail.co
# 318559                                lisa.bills@enron.co
# 9821                                 dsciullo@bw-legal.co
# 99200                                all.houston@enron.co
# 469923      kate.symes@enron.com, brooklyn.couch@enron.co
#
#                                                   Subject  \
# 86994                    Revised EOL Download - PLEASE US
# 144846                                Yahoo! Breaking New
# 427691                                                SIT
# 322555                                      SWPC Agreemen
# 81652                       Corrected Version of Scenario
# 325128    TRV Notification:  (NG - PROPT P/L - 10/19/2001
# 216804   Research Get-Together at Sandeep Kohli's New Hom
# 384495         Draft of Unit Contingent Term Sheet Outlin
# 468495                                                NaN
# 510349  We have length at Colstrip all hours on Monday...
# 75218                      Changes and Updates to SOLUTIO
# 481488                  Ken Lay and Jeff Skilling on CNNf
# 285894                Over 7.5 Bcf/d Sendout in Californi
# 266597                                                 Re
# 169556                         ClickAtHome is Coming Soon
# 360145                  Ken Lay and Jeff Skilling on CNNf
# 405590              a second look at cap. release questio
# 389359                                        Re: Lunchin
# 347314                                      Spot Agreemen
# 362312                                           WEN lunc
# 288446                            ETC - Event - China Tri
# 76606   Lay Talking Points with Davis - Enron's Positi...
# 309191                Revised form of Memorandum of Optio
# 448337            Start Date- 1/27/02; HourAhead hour: 22
# 32931                         FW: Nuclear Rolling Forecas
# 370830                                   Performance Bond
# 434797             Request for Rehearing (Revised July 18
# 311527                                  Tax representatio
# 439932  V010003 - Comments Regarding Retail Electricit...
# 348576                                        PNM proposa
# 102561                         Enron Nom for March 7, 200
# 89430                                                Sith
# 286405                 Enron to wants know what you think
# 62778                                 Updated State Matri
# 422459  Goldman International & Deutsche Bank - Revisi...
# 188656                                                NaN
# 153297  Re: Update on Fountain Valley Power (PSCo Deal...
# 374477                                               Book
# 287994  Important - Please Read - SAP COE HOTLINE NAME...
# 366995                                                NaN
# 260651                                          Two thing
# 410840                        so ya wanna be a FERC lawye
# 155818                                      Re: Tana Jone
# 84297                                               numbe
# 173094   Re: EEI CEO Uniform Business Practices Task Forc
# 2907                                                 Enro
# 318559                              RE: GE Conference Cal
# 9821                                                  NaN
# 99200             Metro 214 and 216 downtown route change
# 469923                                        Can You Hel
#
#                                                        Cc  Mime-Version  \
# 86994                                                None           1.0
# 144846                                               None           1.0
# 427691                                               None           1.0
# 322555                                               None           1.0
# 81652   harry.kingerski@enron.com, iris.waser@enron.co...           1.0
# 325128                                               None           1.0
# 216804                                               None           1.0
# 384495                                               None           1.0
# 468495                                               None           1.0
# 510349   diana.scholtes@enron.com, sean.crandall@enron.co           1.0
# 75218                                                None           1.0
# 481488                                               None           1.0
# 285894  tk.lohman@enron.com, christine.stokes@enron.co...           1.0
# 266597                                               None           1.0
# 169556                                               None           1.0
# 360145                                               None           1.0
# 405590                                 glen.hass@enron.co           1.0
# 389359                           christi.nicolay@enron.co           1.0
# 347314                                               None           1.0
# 362312                                               None           1.0
# 288446                                               None           1.0
# 76606                                                None           1.0
# 309191           kay.mann@enron.com, carlos.sole@enron.co           1.0
# 448337  albert.meyers@enron.com, bill.williams@enron.c...           1.0
# 32931                                                None           1.0
# 370830                                               None           1.0
# 434797                                               None           1.0
# 311527  areynaud@coral-energy.com, dwhaley@coral-energ...           1.0
# 439932  richard.shapiro@enron.com, james.steffes@enron...           1.0
# 348576                                               None           1.0
# 102561                                               None           1.0
# 89430                                                None           1.0
# 286405                                               None           1.0
# 62778                          elizabeth.linnell@enron.co           1.0
# 422459                                               None           1.0
# 188656                                               None           1.0
# 153297                                               None           1.0
# 374477                                               None           1.0
# 287994                                               None           1.0
# 366995                                               None           1.0
# 260651                                               None           1.0
# 410840                                               None           1.0
# 155818                                               None           1.0
# 84297                                                None           1.0
# 173094                      waters-davis@reliantenergy.co           1.0
# 2907                                                 None           1.0
# 318559                                               None           1.0
# 9821                                                 None           1.0
# 99200                                                None           1.0
# 469923                                               None           1.0
#
#                        Content-Type  ...  \
# 86994   text/plain; charset=us-asci  ...
# 144846  text/plain; charset=us-asci  ...
# 427691  text/plain; charset=us-asci  ...
# 322555  text/plain; charset=us-asci  ...
# 81652   text/plain; charset=us-asci  ...
# 325128  text/plain; charset=us-asci  ...
# 216804  text/plain; charset=us-asci  ...
# 384495  text/plain; charset=us-asci  ...
# 468495  text/plain; charset=us-asci  ...
# 510349  text/plain; charset=us-asci  ...
# 75218   text/plain; charset=us-asci  ...
# 481488  text/plain; charset=us-asci  ...
# 285894  text/plain; charset=us-asci  ...
# 266597  text/plain; charset=us-asci  ...
# 169556  text/plain; charset=us-asci  ...
# 360145  text/plain; charset=us-asci  ...
# 405590  text/plain; charset=us-asci  ...
# 389359  text/plain; charset=us-asci  ...
# 347314  text/plain; charset=us-asci  ...
# 362312  text/plain; charset=us-asci  ...
# 288446  text/plain; charset=us-asci  ...
# 76606   text/plain; charset=us-asci  ...
# 309191  text/plain; charset=us-asci  ...
# 448337  text/plain; charset=us-asci  ...
# 32931   text/plain; charset=us-asci  ...
# 370830  text/plain; charset=us-asci  ...
# 434797  text/plain; charset=us-asci  ...
# 311527  text/plain; charset=us-asci  ...
# 439932  text/plain; charset=us-asci  ...
# 348576  text/plain; charset=us-asci  ...
# 102561  text/plain; charset=us-asci  ...
# 89430   text/plain; charset=us-asci  ...
# 286405  text/plain; charset=us-asci  ...
# 62778   text/plain; charset=us-asci  ...
# 422459  text/plain; charset=us-asci  ...
# 188656  text/plain; charset=us-asci  ...
# 153297  text/plain; charset=us-asci  ...
# 374477  text/plain; charset=us-asci  ...
# 287994  text/plain; charset=us-asci  ...
# 366995  text/plain; charset=us-asci  ...
# 260651  text/plain; charset=us-asci  ...
# 410840  text/plain; charset=us-asci  ...
# 155818  text/plain; charset=us-asci  ...
# 84297   text/plain; charset=us-asci  ...
# 173094  text/plain; charset=us-asci  ...
# 2907    text/plain; charset=us-asci  ...
# 318559  text/plain; charset=us-asci  ...
# 9821    text/plain; charset=us-asci  ...
# 99200   text/plain; charset=us-asci  ...
# 469923  text/plain; charset=us-asci  ...
#
#                                                    X-From  \
# 86994   Symes, Kate </O=ENRON/OU=NA/CN=RECIPIENTS/CN=K...
# 144846  "Yahoo! Alerts - Breaking News" <alerts-breaki...
# 427691                                     Sara Shackleto
# 322555                                      Mitch Robinso
# 81652                                        Jeff Dasovic
# 325128  McLaughlin Jr., Errol </O=ENRON/OU=NA/CN=RECIP...
# 216804                                    Shirley Crensha
# 384495                                       Stuart Zisma
# 468495                                        Sharen Caso
# 510349  Semperger, Cara </O=ENRON/OU=NA/CN=RECIPIENTS/...
# 75218                                      James D Steffe
# 481488                                    Public Relation
# 285894                                     Jeffery Fawcet
# 266597                                     John J Lavorat
# 169556                                         Clickathom
# 360145                                    Public Relation
# 405590                                         Susan Scot
# 389359                                     Elizabeth Sage
# 347314                                   Debra Perlingier
# 362312                                   Debra Perlingier
# 288446  Teal, Donna </O=ENRON/OU=NA/CN=RECIPIENTS/CN=N...
# 76606                                      James D Steffe
# 309191                                   Kathleen Carnaha
# 448337        Schedule Crawler<pete.davis@enron.com>@ENRO
# 32931   Imai, Rika </O=ENRON/OU=NA/CN=RECIPIENTS/CN=RIMAI
# 370830  Ring, Richard </O=ENRON/OU=NA/CN=RECIPIENTS/CN...
# 434797           "Ronald Carroll" <rcarroll@bracepatt.com
# 311527   "George Kutzschbach" <gkutzschbach@fulbright.com
# 439932                                        Robert Fran
# 348576  Miller, Stephanie </O=ENRON/OU=NA/CN=RECIPIENT...
# 102561                   "Melissa Jones" <mjones7@txu.com
# 89430                                     David W Delaine
# 286405                                 Enron Announcement
# 62778                                          Margo Reyn
# 422459                                       Cheryl Nelso
# 188656           "Nancy Ferguson" <fergy4@attbi.com>@ENRO
# 153297                                     Mark E Haedick
# 374477                                      Robin Rodrigu
# 287994                                     SAP COE Hotlin
# 366995  Griffith, John </O=ENRON/OU=NA/CN=RECIPIENTS/C...
# 260651  Oxley, David </O=ENRON/OU=NA/CN=RECIPIENTS/CN=...
# 410840                                         Susan Scot
# 155818                                     Mark E Haedick
# 84297                                    Choirmats@aol.co
# 173094                "Michael McGrath" <MMcGrath@eei.org
# 2907                                       Phillip K Alle
# 318559                                            Kay Man
# 9821    Bailey, Susan </O=ENRON/OU=NA/CN=RECIPIENTS/CN...
# 99200                                  Enron Announcement
# 469923                                         Mark Confe
#
#                                                      X-To  \
# 86994   DL-Portland Real Time Shift </O=ENRON/OU=NA/CN...
# 144846                              mike.grigsby@enron.co
# 427691                                Michael Khajeh-Noor
# 322555                                            Kay Man
# 81652                                        Jeff Dasovic
# 325128  Arnold, John </O=ENRON/OU=NA/CN=RECIPIENTS/CN=...
# 216804  Vince J Kaminski, Stinson Gibner, Pinnamaneni ...
# 384495  Elizabeth Sager, Greg Johnston, Scott Healy, K...
# 468495                           Kate Symes, Carla Hoffma
# 510349  Portland Shift </O=ENRON/OU=NA/CN=RECIPIENTS/C...
# 75218    robert neusteadter, Jeff Dasovich, Jennifer Thom
# 481488                                   All Enron Housto
# 285894                          Steven Harris, Kevin Hyat
# 266597  Gorny, Vladimir </o=ENRON/ou=NA/cn=Recipients/...
# 169556                               ClickAtHome@enron.co
# 360145                                   All Enron Housto
# 405590                       Elizabeth Brown, Lindy Donoh
# 389359                                      Barbara N Gra
# 347314                                  akoelemay@cogc.co
# 362312                                   gruyinc@flash.ne
# 288446  Landau, Georgi </O=ENRON/OU=NA/CN=RECIPIENTS/C...
# 76606   David W Delainey, Steven J Kean, Richard Shapi...
# 309191                                        Herman Mani
# 448337  Davis, Pete </O=ENRON/OU=NA/CN=RECIPIENTS/CN=P...
# 32931   Ballato, Russell </O=ENRON/OU=NA/CN=RECIPIENTS...
# 370830  Gunter, Nichole </O=ENRON/OU=NA/CN=RECIPIENTS/...
# 434797  <linda.robertson3@att.net>, "Dan Watkiss" <dwa...
# 311527  Ben.F.Jacoby@enron.com, Kay.Mann@enron.com, JK...
# 439932                           retailelectricity@ftc.go
# 348576  Nemec, Gerald </O=ENRON/OU=NA/CN=RECIPIENTS/CN...
# 102561  daren.j.farmer@enron.com, "Gary Green" <ggreen...
# 89430                             Jeff Donahue, Todd Busb
# 286405                                 All Enron Worldwid
# 62778   Sue Nord, Scott Bolton, Marchris Robinson, Jef...
# 422459                    Stephanie Panus, Sara Shackleto
# 188656  Jones, Tana </O=ENRON/OU=NA/CN=RECIPIENTS/CN=T...
# 153297                                         Alan Larse
# 374477                              Virendra Patel, Wei H
# 287994  ISC ORG ALL GROUPS, ENRON COE PRODUCTION SAP U...
# 366995  Quigley, Dutch </O=ENRON/OU=NA/CN=RECIPIENTS/C...
# 260651  Kitchen, Louise </O=ENRON/OU=NA/CN=RECIPIENTS/...
# 410840              "Ann M. Hebert" <ahebert@akingump.com
# 155818                                      Louise Kitche
# 84297                                 dana.davis@enron.co
# 173094                          <Stanley.Horton@enron.com
# 2907                                  Jedglick@hotmail.co
# 318559                                          Lisa Bill
# 9821                               'dsciullo@bw-legal.com
# 99200                                    All Enron Housto
# 469923                          Kate Symes, Brooklyn Couc
#
#                                                      X-cc X-bcc  \
# 86994                                                 NaN   NaN
# 144846                                                NaN   NaN
# 427691                                                NaN   NaN
# 322555                                                NaN   NaN
# 81652   Harry Kingerski, Iris Waser, James D Steffes, ...   NaN
# 325128                                                NaN   NaN
# 216804                                                NaN   NaN
# 384495                                                NaN   NaN
# 468495                                                NaN   NaN
# 510349  Scholtes, Diana </O=ENRON/OU=NA/CN=RECIPIENTS/...   NaN
# 75218                                                 NaN   NaN
# 481488                                                NaN   NaN
# 285894  TK Lohman, Christine Stokes, Michelle Lokay, L...   NaN
# 266597                                                NaN   NaN
# 169556                                                NaN   NaN
# 360145                                                NaN   NaN
# 405590                                           Glen Has   NaN
# 389359                                   Christi L Nicola   NaN
# 347314                                                NaN   NaN
# 362312                                                NaN   NaN
# 288446                                                NaN   NaN
# 76606                                                 NaN   NaN
# 309191                               Kay Mann, Carlos Sol   NaN
# 448337  Meyers, Albert </O=ENRON/OU=NA/CN=RECIPIENTS/C...   NaN
# 32931                                                 NaN   NaN
# 370830                                                NaN   NaN
# 434797                                                NaN   NaN
# 311527  areynaud@coral-energy.com, dwhaley@coral-energ...   NaN
# 439932   Richard Shapiro, James D Steffes, Harry Kingersk   NaN
# 348576                                                NaN   NaN
# 102561                                                NaN   NaN
# 89430                                                 NaN   NaN
# 286405                                                NaN   NaN
# 62778                                    Elizabeth Linnel   NaN
# 422459                                                NaN   NaN
# 188656                                                NaN   NaN
# 153297                                                NaN   NaN
# 374477                                                NaN   NaN
# 287994                                                NaN   NaN
# 366995                                                NaN   NaN
# 260651                                                NaN   NaN
# 410840                                                NaN   NaN
# 155818                                                NaN   NaN
# 84297                                                 NaN   NaN
# 173094                    <waters-davis@reliantenergy.com   NaN
# 2907                                                  NaN   NaN
# 318559                                                NaN   NaN
# 9821                                                  NaN   NaN
# 99200                                                 NaN   NaN
# 469923                                                NaN   NaN
#
#                                                  X-Folder      X-Origin  \
# 86994           \CDEAN2 (Non-Privileged)\Dean, Craig\Inbo         DEAN-
# 144846  \Michael_Grigsby_Jun2001\Notes Folders\Notes inbo      Grigsby-
# 427691  \Sara_Shackleton_Dec2000_June2001_1\Notes Fold...   SHACKLETON-
# 322555     \Kay_Mann_June2001_4\Notes Folders\Westinghous         MANN-
# 81652           \Jeff_Dasovich_June2001\Notes Folders\Sen     DASOVICH-
# 325128                       \LMAY2 (Non-Privileged)\Inbo          May-
# 216804  \Vincent_Kaminski_Jun2001_2\Notes Folders\Disc...     Kaminski-
# 384495  \Elizabeth_Sager_Dec2000\Notes Folders\All doc...        Sager-
# 468495  \kate symes 6-27-02\Notes Folders\Discussion t...        SYMES-
# 510349           \ExMerge - Williams III, Bill\Preschedul    WILLIAMS-W
# 75218    \Jeff_Dasovich_June2001\Notes Folders\Notes inbo     DASOVICH-
# 481488    \Mark_Taylor _Dec_2000\Notes Folders\Notes inbo       Taylor-
# 285894  \Michelle_Lokay_Dec2000_June2001_1\Notes Folde...        LOKAY-
# 266597                                 \jlavora\Sent Item     Lavorado-
# 169556     \John_Hodge_Nov2001\Notes Folders\All document        HODGE-
# 360145  \Debra_Perlingiere_Dec2000_June2001_1\Notes Fo...  PERLINGIERE-
# 405590  \Susan_Scott_Dec2000_June2001_1\Notes Folders\...        SCOTT-
# 389359         \Elizabeth_Sager_Nov2001\Notes Folders\Sen        Sager-
# 347314  \Gerald_Nemec_Dec2000_June2001_2\Notes Folders...        NEMEC-
# 362312  \Debra_Perlingiere_Dec2000_June2001_2\Notes Fo...  PERLINGIERE-
# 288446                   \MLOKAY (Non-Privileged)\Persona        Lokay-
# 76606    \Jeff_Dasovich_June2001\Notes Folders\Notes inbo     DASOVICH-
# 309191    \Kay_Mann_June2001_1\Notes Folders\All document         MANN-
# 448337              \ExMerge - Solberg, Geir\Deleted Item      SOLBERG-
# 32931       \RBENSON (Non-Privileged)\Benson, Robert\Inbo       Benson-
# 370830               \RRING (Non-Privileged)\Deleted Item         Ring-
# 434797  \Richard_Shapiro_Nov2001\Notes Folders\All doc...      SHAPIRO-
# 311527  \Kay_Mann_June2001_2\Notes Folders\Discussion ...         MANN-
# 439932  \Richard_Shapiro_June2001\Notes Folders\Retail...      SHAPIRO-
# 348576  \Nemec, Gerald (Non-Privileged)\Nemec, Gerald\...        Nemec-
# 102561  \Darren_Farmer_Jun2001\Notes Folders\All document       Farmer-
# 89430   \David_Delainey_Dec2000\Notes Folders\All docu...     Delainey-
# 286405  \Michelle_Lokay_Dec2000_June2001_1\Notes Folde...        LOKAY-
# 62778   \Jeff_Dasovich_Dec2000\Notes Folders\All document     DASOVICH-
# 422459  \Sara_Shackleton_Dec2000_June2001_2\Notes Fold...   SHACKLETON-
# 188656               \Tana_Jones_Jan2002\Jones, Tana\Inbo        Jones-
# 153297  \Mark_Haedicke_Oct2001\Notes Folders\All document     HAEDICKE-
# 374477          \Robin_Rodrique_Jun2001\Notes Folders\Sen     Rodrique-
# 287994  \Michelle_Lokay_Dec2000_June2001_1\Notes Folde...        LOKAY-
# 366995             \ExMerge - Quigley, Dutch\_Exchange_Po      QUIGLEY-
# 260651            \ExMerge - Kitchen, Louise\Deleted Item      KITCHEN-
# 410840  \Susan_Scott_Dec2000_June2001_1\Notes Folders\Sen        SCOTT-
# 155818           \Mark_Haedicke_Oct2001\Notes Folders\Sen     HAEDICKE-
# 84297             \Dana_Davis_Dec2000\Notes Folders\Churc        Davis-
# 173094  \Stanley_Horton_1\Notes Folders\Discussion thread       HORTON-
# 2907             \Phillip_Allen_Dec2000\Notes Folders\Sen        Allen-
# 318559             \Kay_Mann_June2001_3\Notes Folders\Sen         MANN-
# 9821    \SBAILE2 (Non-Privileged)\Bailey, Susan\Delete...       Bailey-
# 99200       \Frank_Ermis_Dec2000\Notes Folders\Notes inbo        Ermis-
# 469923  \kate symes 6-27-02\Notes Folders\Discussion t...        SYMES-
#
#                                 X-FileName has_other_content if_forwarded  \
# 86994          CDEAN2 (Non-Privileged).pst             False        False
# 144846                         mgrigsb.nsf             False        False
# 427691                        sshackle.nsf             False        False
# 322555                           kmann.nsf             False        False
# 81652                         jdasovic.nsf             False        False
# 325128          LMAY2 (Non-Privileged).pst             False        False
# 216804                         vkamins.nsf             False        False
# 384495                          esager.nsf             False        False
# 468495              kate symes 6-27-02.nsf             False        False
# 510349                                 NaN             False        False
# 75218                         jdasovic.nsf             False        False
# 481488                         mtaylor.nsf             False        False
# 285894                          mlokay.nsf             False        False
# 266597                         jlavora.pst             False        False
# 169556                         jhodge2.nsf             False        False
# 360145                         dperlin.nsf             False        False
# 405590                         sscott3.nsf             False        False
# 389359                          esager.nsf             False        False
# 347314                          gnemec.nsf             False        False
# 362312                         dperlin.nsf             False        False
# 288446         MLOKAY (Non-Privileged).pst             False        False
# 76606                         jdasovic.nsf             False        False
# 309191                           kmann.nsf             False        False
# 448337            geir solberg 6-26-02.PST             False        False
# 32931         RBENSON (Non-Privileged).pst             False        False
# 370830         RRING (Non-Privileged)1.pst             False        False
# 434797                        rshapiro.nsf             False        False
# 311527                           kmann.nsf             False        False
# 439932                        rshapiro.nsf             False        False
# 348576  Nemec, Gerald (Non-Privileged).pst             False        False
# 102561                         dfarmer.nsf             False        False
# 89430                          ddelain.nsf             False        False
# 286405                          mlokay.nsf             False        False
# 62778                         jdasovic.nsf             False        False
# 422459                        sshackle.nsf             False        False
# 188656         tjones (Non-Privileged).pst             False        False
# 153297                         mhaedic.nsf             False        False
# 374477                         rrodri2.nsf             False        False
# 287994                          mlokay.nsf             False        False
# 366995           dutch quigley 6-26-02.PST             False        False
# 260651           louise kitchen 2-7-02.pst             False        False
# 410840                         sscott3.nsf             False        False
# 155818                         mhaedic.nsf             False        False
# 84297                          ddavis2.nsf             False        False
# 173094                         shorton.nsf             False        False
# 2907                            pallen.nsf             False        False
# 318559                           kmann.nsf             False        False
# 9821          SBAILE2 (Non-Privileged).pst             False        False
# 99200                           fermis.nsf             False        False
# 469923              kate symes 6-27-02.nsf             False        False
#
#                               Main_To
# 86994      shift.dl-portland@enron.co
# 144846          mike.grigsby@enron.co
# 427691  michael.khajeh-noori@enron.co
# 322555              kay.mann@enron.co
# 81652          jeff.dasovich@enron.co
# 325128          john.arnold@enron.com
# 216804       vince.kaminski@enron.com
# 384495      elizabeth.sager@enron.com
# 468495           kate.symes@enron.com
# 510349        shift.portland@enron.co
# 75218    robert.neusteadter@enron.com
# 481488           all.houston@enron.co
# 285894        steven.harris@enron.com
# 266597        vladimir.gorny@enron.co
# 169556           clickathome@enron.co
# 360145           all.houston@enron.co
# 405590      elizabeth.brown@enron.com
# 389359          barbara.gray@enron.co
# 347314              akoelemay@cogc.co
# 362312               gruyinc@flash.ne
# 288446         georgi.landau@enron.co
# 76606        david.delainey@enron.com
# 309191          herman.manis@enron.co
# 448337            pete.davis@enron.co
# 32931       russell.ballato@enron.com
# 370830        nichole.gunter@enron.co
# 434797       linda.robertson3@att.net
# 311527         ben.f.jacoby@enron.com
# 439932       retailelectricity@ftc.go
# 348576          gerald.nemec@enron.co
# 102561       daren.j.farmer@enron.com
# 89430          jeff.donahue@enron.com
# 286405         all.worldwide@enron.co
# 62778              sue.nord@enron.com
# 422459      stephanie.panus@enron.com
# 188656            tana.jones@enron.co
# 153297           alan.larsen@enron.co
# 374477       virendra.patel@enron.com
# 287994           isc.groups@enron.com
# 366995         dutch.quigley@enron.co
# 260651       louise.kitchen@enron.com
# 410840            ahebert@akingump.co
# 155818        louise.kitchen@enron.co
# 84297             dana.davis@enron.co
# 173094        stanley.horton@enron.co
# 2907              jedglick@hotmail.co
# 318559            lisa.bills@enron.co
# 9821             dsciullo@bw-legal.co
# 99200            all.houston@enron.co
# 469923           kate.symes@enron.com
#
# [50 rows x 22 columns]

# %%
for i in range(50):
    # print the content of the first 50 emails
    print(f"Email {i+1}:")
    print("--------------------------------------------------")
    print(sample_emails.iloc[i]['content'])
    print("--------------------------------------------------")
# Out:
# Email 1:
# --------------------------------------------------
# I believe all the bugs have been worked out of this one. It pulls in inter-desk swaps and includes all the features you guys have requested - sorts by delivery point or hour, able to refresh, etc.
#
# I've saved the download as EOL Download (in P://Real Time/Increment/Windows 2000) and deleted the file called NEW EOL DOWNLOAD. Test is out and let me know what you think.
#
# Thanks.
#
# Kate Symes
# Real Time Trading Support
# Office/503-464-7744
# Cell/503-819-2181
# Fax/503-464-7996
#
#
# --------------------------------------------------
# Email 2:
# --------------------------------------------------
# Yahoo! News	Edit Breaking News Alerts - Yahoo!
#
#
#
# 	Breaking News Alert	 edit
# DAMASCUS, Syria _ Pope John Paul II arrives in Syria.
#
# 	Click here!
# 	[IMAGE]
#
#
#
# If you no longer wish to receive this alert, click here to unsubscribe.
# If you have questions, send us feedback.
#
# Copyright , 1994-2001 Yahoo! Inc. All rights reserved. Yahoo Privacy Policy
# --------------------------------------------------
# Email 3:
# --------------------------------------------------
# Are you still working every other day?  Please see my SITA message to Sharon
# Lewis and let me know the most efficient way of proceeding.  Thanks.  Sara
# --------------------------------------------------
# Email 4:
# --------------------------------------------------
# Kay -
#
# I've reached a verbal agreement with Westinghouse on the LD issues.  I've
# attached a letter outlining the agreement.  Could you review from a legal
# standpoint?  Call me with questions.
#
# Thanks,
#
# Mitch
#
# --------------------------------------------------
# Email 5:
# --------------------------------------------------
# This copy should correct all of the the typos identified on the call this
# morning.  Apologies if I've missed any.
#
# Best,
# Jeff
# --------------------------------------------------
# Email 6:
# --------------------------------------------------
# The report named: NG - PROPT P/L <http://trv.corp.enron.com/linkFromExcel.asp?report_cd=11&report_name=NG+-+PROPT+P/L&category_cd=5&category_name=FINANCIAL&toc_hide=1&sTV1=5&TV1Exp=Y&current_efct_date=10/19/2001>, published as of 10/19/2001 is now available for viewing on the website.
# --------------------------------------------------
# Email 7:
# --------------------------------------------------
# Hi everyone.
#
# Please rsvp to me by tomorrow if you will be attending the party on Saturday.
#
# If you plan on attending, please let me know what dish you will bring.
#
# Thanks!
#
# Shirley
#
#
# --------------------------------------------------
# Email 8:
# --------------------------------------------------
# I have been asked by numerous parties to put together a rough outline for
# items which require consideration in connection with Unit Contingent PPA's
# (as opposed to the typical commodity form of PPA).  Attached is a quick cut
# that I threw together.  Please take a look and provide me with any
# coments/suggestions that you might have to enhance this document.  Thanks in
# advance for your time and effort.
#
# Stuart
#
# --------------------------------------------------
# Email 9:
# --------------------------------------------------
# Deal # 460860 is entered as flowing every day of the week.  Is this correct?
# Please let me know when it is changed.
#
# Thanks!
# --------------------------------------------------
# Email 10:
# --------------------------------------------------
# We are 7 MW long all hours at Montana System,  which is our buy from MPC, deal number 615780.1
#
# The upstream is PSEI-DUKE-WWP-MPCO.
#
# We put in a false schedule to Smurfit to get flat preschedule, and that tag is 23795.
#
# When we get close to HE 0100 on Monday, that Tag needs to go away, and the energy needs to be sold.
#
# Please don't say it was a false preschedule, just say that it was 'unexpectedly ramped down' or something.
#
# Enpower accurately reflects the length at Montana System
#
# Cara
# --------------------------------------------------
# Email 11:
# --------------------------------------------------
# Robert --
#
# Pls take a look.  We have some need for serious data inclusions and changes
# from Tamara.  I restructured the charts.  Hope this makes sense.
#
# I also don't understand the Direct Access Benefits to CDWR table - Are the
# savings monthly, annually, total???
#
# We need to add Jeff's section on Natural Gas.
#
# Please everyone check out what I said about a California Demand Buy-Down
# system that should be in place until Retail Rate structure is changed.  Not
# sure if everyone wants this much detail or if this contradicts anything else
# we have put out.
#
# The goal is to get this to Janel by 3pm Friday for her to include in a Draft
# Package for Steve over the weekend with final revisions on Monday.
#
# I appreciate everyone's help.
#
# Thanks,
#
# Jim
# --------------------------------------------------
# Email 12:
# --------------------------------------------------
# Ken Lay and Jeff Skilling were interviewed on CNNfn to discuss the succession
# of Jeff to CEO of Enron.  We have put the interview on IPTV for your viewing
# pleasure.  Simply point your web browser to http://iptv.enron.com, click the
# link for special events, and then choose "Enron's Succession Plan."  The
# interview will be available every 15 minutes through Friday, Dec. 15.
# --------------------------------------------------
# Email 13:
# --------------------------------------------------
# Take a look at the California send out numbers for 11/15 and 11/16.  We're
# really pushing the envelope here.  Collectively, SoCal and PG&E are having to
# withdraw over 2 Bcf/d in order to meet demand.  This situation is precisely
# what we've predicted would happen in a gas short marketplace.  Look for this
# shortage to be exacerbated in the next few years with the addition of the new
# EOC power plants, particularly, when the power is most likely going to be
# used to serve native markets, not the Cal. ISO/PX with its "price cap"
# feature.
#
#
# --------------------------------------------------
# Email 14:
# --------------------------------------------------
# Hickerson always claims that they have var by trader.
# --------------------------------------------------
# Email 15:
# --------------------------------------------------
# Want a NEW high speed computer?
#
# 866 MHz Pentium III Processor FAST enough?
#
# Want High Speed internet?
# Broadband,
# Cable Modem,
# DSL,
# Satellite.
#
# Then Get READY...
# All Eligible U.S. Employees get innovative at HOME beginning March, 2001.
#
# Go to http://clickathome.enron.com to LEARN more about the offerings.
#
# Non-U.S. Eligible Employees get innovative at home beginning late 2001 and
# 2002.
# --------------------------------------------------
# Email 16:
# --------------------------------------------------
# Ken Lay and Jeff Skilling were interviewed on CNNfn to discuss the succession
# of Jeff to CEO of Enron.  We have put the interview on IPTV for your viewing
# pleasure.  Simply point your web browser to http://iptv.enron.com, click the
# link for special events, and then choose "Enron's Succession Plan."  The
# interview will be available every 15 minutes through Friday, Dec. 15.
# --------------------------------------------------
# Email 17:
# --------------------------------------------------
# Can we keep the upside -- I believe the answer is clearly "no" unless/until
# we get a favorable ruling on our share-the-upside filing.  Til then we're
# bound by the billing provisions on Sheet 95H.
# Sometimes the answers clarify themselves after you leave the question sitting
# out there a while...
#
# As for the contract rights of replacement shippers, I would say the tariff
# language gives us some leeway on whether to automatically give replacement
# shipper the releasing shipper's discount at alt. points.  If we don't, and
# the replacement shipper uses an alt. point and has to pay max rate, releasing
# shipper gets a refund under our billing provision.  I know Lindy has some
# clear ideas on what we want here... we can discuss more if you like.
# --------------------------------------------------
# Email 18:
# --------------------------------------------------
# Don't go without me ... I can't go this week  ... or next week, other than
# Wed. (does that work?).  The week after that, and the week after that, and
# the week after that, .... look fine too.
# --------------------------------------------------
# Email 19:
# --------------------------------------------------
# Dear Mr. Koelemay:
#
# At the request of Mark Whitt,  I am sending you  the attached draft of a
# Master Spot Purchase/Sale Agreement between Enron North America Corp. and
# Citation Oil & Gas Corp.  for your review.
#
# Please do not hesitate to give me a call with any questions you may have
# regarding the enclosed.
#
#
#
#
# Very truly yours,
# Debra Perlingiere
# Enron North America Corp.
# Legal Department
# 1400 Smith Street, EB 3885
# Houston, Texas 77002
# dperlin@enron.com
# Phone 713-853-7658
# Fax  713-646-3490
# --------------------------------------------------
# Email 20:
# --------------------------------------------------
# My RSVP for June Lunch.
#
# Thanks
#
# Debra Perlingiere
# Enron North America Corp.
# Legal Department
# 1400 Smith Street, EB 3885
# Houston, Texas 77002
# dperlin@enron.com
# Phone 713-853-7658
# Fax  713-646-3490
# --------------------------------------------------
# Email 21:
# --------------------------------------------------
# Attached is the information on the May 2002 China trip.
#
# If interested please contact Georgi Landau at ext. 54435.
#
#
#
# --------------------------------------------------
# Email 22:
# --------------------------------------------------
# Attached is a set of draft talking points for Lay to discuss with Governor
# Davis related to not opposing California's takeover of the transmission
# network.  Please let me know if anyone has any comments.
#
# Jim
#
# --------------------------------------------------
# Email 23:
# --------------------------------------------------
# Herman,
#
# Attached is a revised form of Memorandum of Option for your review.  We have
# revised it to be consistent with our form of Option to Purchase.
#
# Please advise if these revisions are acceptable.
#
# Thanks
#
#
#
# Kathleen Carnahan
# Enron North  America Corp.
# 1400 Smith Street, EB 3146d
# Houston, TX 77002
# Phone - (713) 345-3386
# Fax - (713) 646-3037
# --------------------------------------------------
# Email 24:
# --------------------------------------------------
#
#
# Start Date: 1/27/02; HourAhead hour: 22;  No ancillary schedules awarded.  No variances detected.
#
#     LOG MESSAGES:
#
# PARSING FILE -->> O:\Portland\WestDesk\California Scheduling\ISO Final Schedules\2002012722.txt
# --------------------------------------------------
# Email 25:
# --------------------------------------------------
#
#
# Attached are the two files for this week's nuclear rolling forecast.
# --------------------------------------------------
# Email 26:
# --------------------------------------------------
# Nichole,
#
# The payment information for the Performance Bonds is as follows:
#
# Gas:  	EID# 10028620, Company# 1596, Cost Center# 150255
# Power:	EID# 10002583, Company# 1596, Cost Center# 150256
#
# I will also need to know the specifics for Bond 81538327, PG&E $30,000,000 (Premium $60,000).
#
# Thanks,
#
# Richard
# --------------------------------------------------
# Email 27:
# --------------------------------------------------
# The attached reflect the comments that I received on today's conference
# call.  (I am awaiting comments from Sarah and Linda.)  Except for filling in
# the cites and a final stylistic readthrough, the draft is essentially final.
# (In light of some of the inserts that I received today, it is possible that
# the draft may be redundant in certain places and may need a little
# wordsmithing.)  Please let me know asap if you have any comments.
#
# I have sent a copy to Constellation Power Source.
#
#  - #145352 v4 - REHEARING RESAVED MONDAY.doc
#  - REDLINE DOC.rtf
# --------------------------------------------------
# Email 28:
# --------------------------------------------------
# The tax representation which should be included in Section 6(d) of the
# Letter Agreement is as follows:
#
# Since its formation, the LLC has not made any tax elections on behalf
# of the LLC, including any tax election that causes the LLC to be treated
# as anything other than a disregarded entity in accordance with Income
# Tax Regulations section 301.7701-3(b).
# --------------------------------------------------
# Email 29:
# --------------------------------------------------
# Attached for filing in docket V010003 are Enron Corp.'s comments.  Hard
# copies have been sent by U.S. mail.
#
# Thank you for your assistance in this matter - if you have any questions,
# please contact me.
#
# Bob Frank
# 713-853-3180
#
#
#
#
#
#
#
# --------------------------------------------------
# Email 30:
# --------------------------------------------------
#
# Should have sent you this version:
#
# Steph
#
#
# --------------------------------------------------
# Email 31:
# --------------------------------------------------
# (See attached file: HPLN0307.xls)
#
#  - HPLN0307.xls
# --------------------------------------------------
# Email 32:
# --------------------------------------------------
# Guys, gas with a $5.00 handle is not a good thing for this deal - I know we
# are pushing this restructuring as fast as we can; however, I think we need to
# determine how to move this faster. Any ideas?
#
# Regards
# Delainey
# --------------------------------------------------
# Email 33:
# --------------------------------------------------
# It's almost time to check your pulse...
# --------------------------------------------------
# Email 34:
# --------------------------------------------------
# Attached please find the updated state matrix.  If you have any questions, or
# notice something that needs to be changed, please let me know.
#
# Thanks!
#
#
#
#
# Margo Reyna
# Regulatory Analyst
# Enron Corp., Government Affairs
# Phone:  713-853-9191
# --------------------------------------------------
# Email 35:
# --------------------------------------------------
# Hi Stephanie, I will get the final version of ECT - Goldman International
# agreement by the end of the day  onThursday and there is a lot of pressure to
# get it executed right away.   Tomorrow can you prepare and execute the
# accompanying documents.  For ECT's Authorized Traders List, you need to add
# Mark Schlueter (doublecheck spelling and phone number) to the list of
# traders.  This is a HIGH priority.
#
# Please also revise the the trader list for both the ENA (add Peter Schluter)
# and ECT  (add Mark) in order to execute the Deutsche Bank agreements we
# discussed today.   We also got calls today about getting this one executed
# since we already have signatures from Deutsche Bank.
#
# Thanx.
#
# Cheryl Nelson
# Senior Counsel
# EB3816
# (713) 345-4693
# --------------------------------------------------
# Email 36:
# --------------------------------------------------
#
# You have been on my mind..How are things in your life?  I  am not sure that this is your address but, thought I would give it a  try.
# Nancy Ferguson
# --------------------------------------------------
# Email 37:
# --------------------------------------------------
# Thanks.   Mark
# --------------------------------------------------
# Email 38:
# --------------------------------------------------
# Could you please ensure that these books are set up the same in GRMS as in
# ERMS.  They have been officialized and are still not pulling the positions in
# automatically.  I am having to manually override the post-ids.
#
#  BOOK NAME    6/21/2000 POST-ID
#
#  INTRA-CAND-WEST-PHY  816302
#
#  INTRA-ST-COVE-BAS   816594
#
#  INTRA-ST-COVE-PRC   816593
#
# Thank you,
# Robin
# x57478
# --------------------------------------------------
# Email 39:
# --------------------------------------------------
# Please make note of the following important change to the SAP COE Hotline
# mailbox !
#
# Beginning Monday 11th December, the sap coe hotline will close.
#
# All messages from the ISC Call Center will come from the new mailbox:  isc
# hotline
#
# All messages to the ISC Call Center should be addressed isc hotline
#
# If you are sending an e-mail over the internet, the address will be
# isc.hotline@enron.com
#
# If you have any questions, please call the ISC Call Center at 713-345-4727
#
# Thank you.
# ISC
# --------------------------------------------------
# Email 40:
# --------------------------------------------------
# here are the deltas, let me know if you have any questions.
#
# Thanks,
#
#
# John
#
#
#
# --------------------------------------------------
# Email 41:
# --------------------------------------------------
# Credit
# Bill may want to do a contract for Sachs at around 20/20. He's thinking about it and will let me know. Apparently RWE are chasing him.
#
# NETCo ee's with nearly 5 years service at Enron
# We have about 10 people who had they stayed at Enron estate for another 30 - 60 days would have vested in the Enron pension plan (cash-balance plan). We have tried to find some way to make something work here, but as it stands it looks like the are going to have to transfer on 8th of Feb and forfeit whatever was in this plan (roughly 5% of base salary per year and it is a 5 year service vesting arrangement). You may hear some noise.
#
# David
# --------------------------------------------------
# Email 42:
# --------------------------------------------------
# Part I:  Dress Code for Female FERC Lawyers at FERC Proceedings*
#
# Skirts must be mid-calf length and of a synthetic fabric.
# All clothing worn in FERC hearing rooms must be properly aged (12 years or
# more).
# No solid-colored garments are permitted.  Exceptions:  mauve, pink, peach,
# teal, harvest gold.
# Hair must be fuzzy, multi-colored and must partially conceal the face.
# Suntan hose must be worn at all times.
# Open-toed shoes (preferably in a lighter color than the hem of the skirt) are
# preferred.
# Those with a flair for fashion are permitted to wear inexpensive animal print
# garments, metallic accessories or clothing with fake fur trim, so as to
# attract attention to one's originality.
#
# *also applicable to female practitioners at the Texas Railroad Commission and
# Public Utilities Commission.
# --------------------------------------------------
# Email 43:
# --------------------------------------------------
# Thanks for the comments.  I will make sure Tana gets taken care of.  Mark
# --------------------------------------------------
# Email 44:
# --------------------------------------------------
# Dana,
#
# This is Marylyn's phone number 713-680-0869.  Her email address is
# witness4him@juno.com
#
# later,
#
# Curtis
# --------------------------------------------------
# Email 45:
# --------------------------------------------------
# Stan,
#
# Having circulated the attached meeting summary, action steps, and principles
# to the group, and having heard only affirmative comment, I believe we will
# use the attached as the go forward plan for our CEO meeting.
#
# It is right in line with our earlier discussion.
#
# If you have any questions or comments, please let me know.  I'll be out of
# the country 6/1-6/6.  It would be most appreciated if someone would advise me
# of GISB Board actions as soon as they occur.
#
# Thanks
#   -Mike
#
#  - ubp.ceotf.Maymeet.summary.doc
# --------------------------------------------------
# Email 46:
# --------------------------------------------------
# Jed,
#
#  I understand you have been contacted regarding a telephone interview to
# discuss trading opportunities at  Enron.  I am sending you this message to
# schedule the interview.  Please call or email me with a time that would be
# convenient for you.  I look forward to speaking with you.
#
# Phillip Allen
# West Gas Trading
# pallen@enron.com
# 713-853-7041
# --------------------------------------------------
# Email 47:
# --------------------------------------------------
# I'll be calling in from out of the office, as will Sheila.
# --------------------------------------------------
# Email 48:
# --------------------------------------------------
#
# Dan,
#
# Just wanted to wish you, Jane, Jordan, Cameron a very HAPPY THANKSGIVING.
#
# Steve, Sugarbear & I will be hosting Steve's Mom @ our house.
#
# I am really looking forward to the long weekend, with all the craziness thats been happening @ work.
#
# Well take care, we love you all.
#
#
# Regards,
# Susan S. Bailey
# Senior Legal Specialist
# Enron Wholesale Services
# Legal Department
# 1400 Smith Street, Suite 3803A
# Houston, Texas 77002
# phone: (713) 853-4737
# fax: (713) 646-3490
# email: susan.bailey@ enron.com
# --------------------------------------------------
# Email 49:
# --------------------------------------------------
# Employees who ride Metro bus routes 214 and 216 please note that Monday,
# November 13, 2000, the buses will return to their normal route on Lousiana
# instead of Milam for the afternoon.
# --------------------------------------------------
# Email 50:
# --------------------------------------------------
# Kate, could you help us on deal #595155.1 that is showing up as a purchase
# from Enron Energy Marketing which Brooklyn dose not show any purchases.  This
# deal is Short Term California desk.  We also have a small variance with sales
# but Brooklyn and I still need to review.
#
# Kate I looked for your e-mail and can not find the one you sent me telling me
# what you look over.  Could you please resend it?  thanks.
#
#
# --------------------------------------------------

# %% [markdown]
# # Hierchial Order

# %%
import pandas as pd
import networkx as nx

# Load dataset
df = pd.read_csv(sample_dataset)

# Fill missing 'Cc' with empty string
df['Cc'] = df['Cc'].fillna("")

# Parse edges from 'From' -> 'To' and 'Cc' (but not interpreting direction as superiority)
edges = []
for _, row in df.iterrows():
    sender = row['From']
    to_list = str(row['To']).split(",") if pd.notna(row['To']) else []
    cc_list = str(row['Cc']).split(",") if pd.notna(row['Cc']) else []

    for recipient in to_list + cc_list:
        recipient = recipient.strip()
        if recipient:
            edges.append((sender, recipient))

# Build directed graph
G = nx.DiGraph()
G.add_edges_from(edges)

# Compute centrality metrics
degree_centrality = nx.degree_centrality(G)
betweenness_centrality = nx.betweenness_centrality(G)
closeness_centrality = nx.closeness_centrality(G)
pagerank = nx.pagerank(G)

# %%
metrics = {
    "degree": degree_centrality,
    "betweenness": betweenness_centrality,
    "closeness": closeness_centrality,
    "pagerank": pagerank
}

# Step 4: Function to infer hierarchy
def infer_hierarchy_label(sender, recipient):
    if sender not in G or recipient not in G:
        return "Unknown"
    
    sender_score = sum(metric.get(sender, 0) for metric in metrics.values())
    recipient_score = sum(metric.get(recipient, 0) for metric in metrics.values())

    if sender_score > recipient_score:
        return "Sender higher"
    elif sender_score < recipient_score:
        return "Recipient higher"
    else:
        return "Similar level"

# Step 5: Apply to each row
hierarchy_labels = []
for _, row in df.iterrows():
    sender = row['From']
    recipient = row['Main_To']

    if pd.isna(sender) or pd.isna(recipient):
        hierarchy_labels.append("Unknown")
    else:
        label = infer_hierarchy_label(sender.strip(), recipient.strip())
        hierarchy_labels.append(label)

# Step 6: Add result and save to file
df['Hierarchy_Label'] = hierarchy_labels


df = df[df['Hierarchy_Label'] != 'Unknown']

df.to_csv(sample_dataset, index=False)

print(f"Updated file saved to: {sample_dataset}")
df.head(5)
# Out:
# Updated file saved to: datasets/sample_emails.csv
#                                              message  \
# 0  Message-ID: <31664984.1075852142386.JavaMail.e...
# 1  Message-ID: <5115047.1075855610475.JavaMail.ev...
# 2  Message-ID: <12042696.1075844566306.JavaMail.e...
# 3  Message-ID: <17502456.1075846133538.JavaMail.e...
# 4  Message-ID: <8313323.1075843861667.JavaMail.ev...
#
#                                              content  \
# 0  I believe all the bugs have been worked out of...
# 1  Yahoo! News\tEdit Breaking News Alerts - Yahoo...
# 2  Are you still working every other day?  Please...
# 3  Kay -\n\nI've reached a verbal agreement with ...
# 4  This copy should correct all of the the typos ...
#
#                                      Message-ID  \
# 0  <31664984.1075852142386.JavaMail.evans@thyme
# 1   <5115047.1075855610475.JavaMail.evans@thyme
# 2  <12042696.1075844566306.JavaMail.evans@thyme
# 3  <17502456.1075846133538.JavaMail.evans@thyme
# 4   <8313323.1075843861667.JavaMail.evans@thyme
#
#                                    Date                              From  \
# 0  Wed, 17 Oct 2001 10:19:20 -0700 (PDT               kate.symes@enron.co
# 1   Fri, 4 May 2001 23:13:00 -0700 (PDT  alerts-breakingnews@yahoo-inc.co
# 2  Mon, 11 Sep 2000 06:22:00 -0700 (PDT          sara.shackleton@enron.co
# 3   Thu, 9 Nov 2000 10:05:00 -0800 (PST           mitch.robinson@enron.co
# 4   Wed, 7 Mar 2001 11:11:00 -0800 (PST            jeff.dasovich@enron.co
#
#                               To                           Subject  \
# 0     shift.dl-portland@enron.co  Revised EOL Download - PLEASE US
# 1          mike.grigsby@enron.co               Yahoo! Breaking New
# 2  michael.khajeh-noori@enron.co                               SIT
# 3              kay.mann@enron.co                     SWPC Agreemen
# 4         jeff.dasovich@enron.co     Corrected Version of Scenario
#
#                                                   Cc  Mime-Version  \
# 0                                                              1.0
# 1                                                              1.0
# 2                                                              1.0
# 3                                                              1.0
# 4  harry.kingerski@enron.com, iris.waser@enron.co...           1.0
#
#                   Content-Type  ...  \
# 0  text/plain; charset=us-asci  ...
# 1  text/plain; charset=us-asci  ...
# 2  text/plain; charset=us-asci  ...
# 3  text/plain; charset=us-asci  ...
# 4  text/plain; charset=us-asci  ...
#
#                                                 X-To  \
# 0  DL-Portland Real Time Shift </O=ENRON/OU=NA/CN...
# 1                              mike.grigsby@enron.co
# 2                                Michael Khajeh-Noor
# 3                                            Kay Man
# 4                                       Jeff Dasovic
#
#                                                 X-cc X-bcc  \
# 0                                                NaN   NaN
# 1                                                NaN   NaN
# 2                                                NaN   NaN
# 3                                                NaN   NaN
# 4  Harry Kingerski, Iris Waser, James D Steffes, ...   NaN
#
#                                             X-Folder     X-Origin  \
# 0          \CDEAN2 (Non-Privileged)\Dean, Craig\Inbo        DEAN-
# 1  \Michael_Grigsby_Jun2001\Notes Folders\Notes inbo     Grigsby-
# 2  \Sara_Shackleton_Dec2000_June2001_1\Notes Fold...  SHACKLETON-
# 3     \Kay_Mann_June2001_4\Notes Folders\Westinghous        MANN-
# 4          \Jeff_Dasovich_June2001\Notes Folders\Sen    DASOVICH-
#
#                     X-FileName has_other_content if_forwarded  \
# 0  CDEAN2 (Non-Privileged).pst             False        False
# 1                  mgrigsb.nsf             False        False
# 2                 sshackle.nsf             False        False
# 3                    kmann.nsf             False        False
# 4                 jdasovic.nsf             False        False
#
#                          Main_To   Hierarchy_Label
# 0     shift.dl-portland@enron.co     Sender higher
# 1          mike.grigsby@enron.co  Recipient higher
# 2  michael.khajeh-noori@enron.co     Sender higher
# 3              kay.mann@enron.co  Recipient higher
# 4         jeff.dasovich@enron.co     Similar level
#
# [5 rows x 23 columns]

# %%
import pandas as pd
import networkx as nx

# Load dataset
df = pd.read_csv(sample_dataset)

# Fill missing 'Cc' with empty string
df['Cc'] = df['Cc'].fillna("")

# Parse edges from 'From' -> 'To' and 'Cc'
edges = []
for _, row in df.iterrows():
    sender = row['From']
    to_list = str(row['To']).split(",") if pd.notna(row['To']) else []
    cc_list = str(row['Cc']).split(",") if pd.notna(row['Cc']) else []

    for recipient in to_list + cc_list:
        recipient = recipient.strip()
        if recipient:
            edges.append((sender, recipient))

# Build directed graph
G = nx.DiGraph()
G.add_edges_from(edges)

# Compute centrality metrics
degree = nx.degree_centrality(G)
betweenness = nx.betweenness_centrality(G)
closeness = nx.closeness_centrality(G)
pagerank = nx.pagerank(G)

# Normalize each metric using min-max scaling
def normalize_metric(metric_dict):
    values = list(metric_dict.values())
    min_val = min(values)
    max_val = max(values)
    range_val = max_val - min_val if max_val > min_val else 1e-9
    return {k: (v - min_val) / range_val for k, v in metric_dict.items()}

degree_norm = normalize_metric(degree)
betweenness_norm = normalize_metric(betweenness)
closeness_norm = normalize_metric(closeness)
pagerank_norm = normalize_metric(pagerank)

# Define weights for each centrality metric
weights = {
    "degree": 0.1,
    "betweenness": 0.20,
    "closeness": 0.20,
    "pagerank": 0.5
}

# Aggregate normalized and weighted centralities
combined_score = {}
for node in G.nodes():
    combined_score[node] = (
        weights["degree"] * degree_norm.get(node, 0) +
        weights["betweenness"] * betweenness_norm.get(node, 0) +
        weights["closeness"] * closeness_norm.get(node, 0) +
        weights["pagerank"] * pagerank_norm.get(node, 0)
    )

# Step 4: Function to infer hierarchy
def infer_hierarchy_label(sender, recipient):
    if sender not in G or recipient not in G:
        return "Unknown"
    
    sender_score = combined_score.get(sender, 0)
    recipient_score = combined_score.get(recipient, 0)

    if sender_score > recipient_score:
        return "Sender higher"
    elif sender_score < recipient_score:
        return "Recipient higher"
    else:
        return "Similar level"

# Step 5: Apply to each row
hierarchy_labels = []
for _, row in df.iterrows():
    sender = row['From']
    recipient = row['Main_To']

    if pd.isna(sender) or pd.isna(recipient):
        hierarchy_labels.append("Unknown")
    else:
        label = infer_hierarchy_label(sender.strip(), recipient.strip())
        hierarchy_labels.append(label)

# Step 6: Add result and save to file
df['Hierarchy_Label'] = hierarchy_labels

# Remove rows with 'Unknown' label
df = df[df['Hierarchy_Label'] != 'Unknown']

# Save result
df.to_csv(sample_dataset, index=False)
print(f"Updated file saved to: {sample_dataset}")

df.head(5)
# Out:
# Updated file saved to: datasets/sample_emails.csv
#                                              message  \
# 0  Message-ID: <31664984.1075852142386.JavaMail.e...
# 1  Message-ID: <5115047.1075855610475.JavaMail.ev...
# 2  Message-ID: <12042696.1075844566306.JavaMail.e...
# 3  Message-ID: <17502456.1075846133538.JavaMail.e...
# 4  Message-ID: <8313323.1075843861667.JavaMail.ev...
#
#                                              content  \
# 0  I believe all the bugs have been worked out of...
# 1  Yahoo! News\tEdit Breaking News Alerts - Yahoo...
# 2  Are you still working every other day?  Please...
# 3  Kay -\n\nI've reached a verbal agreement with ...
# 4  This copy should correct all of the the typos ...
#
#                                      Message-ID  \
# 0  <31664984.1075852142386.JavaMail.evans@thyme
# 1   <5115047.1075855610475.JavaMail.evans@thyme
# 2  <12042696.1075844566306.JavaMail.evans@thyme
# 3  <17502456.1075846133538.JavaMail.evans@thyme
# 4   <8313323.1075843861667.JavaMail.evans@thyme
#
#                                    Date                              From  \
# 0  Wed, 17 Oct 2001 10:19:20 -0700 (PDT               kate.symes@enron.co
# 1   Fri, 4 May 2001 23:13:00 -0700 (PDT  alerts-breakingnews@yahoo-inc.co
# 2  Mon, 11 Sep 2000 06:22:00 -0700 (PDT          sara.shackleton@enron.co
# 3   Thu, 9 Nov 2000 10:05:00 -0800 (PST           mitch.robinson@enron.co
# 4   Wed, 7 Mar 2001 11:11:00 -0800 (PST            jeff.dasovich@enron.co
#
#                               To                           Subject  \
# 0     shift.dl-portland@enron.co  Revised EOL Download - PLEASE US
# 1          mike.grigsby@enron.co               Yahoo! Breaking New
# 2  michael.khajeh-noori@enron.co                               SIT
# 3              kay.mann@enron.co                     SWPC Agreemen
# 4         jeff.dasovich@enron.co     Corrected Version of Scenario
#
#                                                   Cc  Mime-Version  \
# 0                                                              1.0
# 1                                                              1.0
# 2                                                              1.0
# 3                                                              1.0
# 4  harry.kingerski@enron.com, iris.waser@enron.co...           1.0
#
#                   Content-Type  ...  \
# 0  text/plain; charset=us-asci  ...
# 1  text/plain; charset=us-asci  ...
# 2  text/plain; charset=us-asci  ...
# 3  text/plain; charset=us-asci  ...
# 4  text/plain; charset=us-asci  ...
#
#                                                 X-To  \
# 0  DL-Portland Real Time Shift </O=ENRON/OU=NA/CN...
# 1                              mike.grigsby@enron.co
# 2                                Michael Khajeh-Noor
# 3                                            Kay Man
# 4                                       Jeff Dasovic
#
#                                                 X-cc X-bcc  \
# 0                                                NaN   NaN
# 1                                                NaN   NaN
# 2                                                NaN   NaN
# 3                                                NaN   NaN
# 4  Harry Kingerski, Iris Waser, James D Steffes, ...   NaN
#
#                                             X-Folder     X-Origin  \
# 0          \CDEAN2 (Non-Privileged)\Dean, Craig\Inbo        DEAN-
# 1  \Michael_Grigsby_Jun2001\Notes Folders\Notes inbo     Grigsby-
# 2  \Sara_Shackleton_Dec2000_June2001_1\Notes Fold...  SHACKLETON-
# 3     \Kay_Mann_June2001_4\Notes Folders\Westinghous        MANN-
# 4          \Jeff_Dasovich_June2001\Notes Folders\Sen    DASOVICH-
#
#                     X-FileName has_other_content if_forwarded  \
# 0  CDEAN2 (Non-Privileged).pst             False        False
# 1                  mgrigsb.nsf             False        False
# 2                 sshackle.nsf             False        False
# 3                    kmann.nsf             False        False
# 4                 jdasovic.nsf             False        False
#
#                          Main_To   Hierarchy_Label
# 0     shift.dl-portland@enron.co     Sender higher
# 1          mike.grigsby@enron.co  Recipient higher
# 2  michael.khajeh-noori@enron.co     Sender higher
# 3              kay.mann@enron.co  Recipient higher
# 4         jeff.dasovich@enron.co     Similar level
#
# [5 rows x 23 columns]

# %%
df = pd.read_csv(sample_dataset)


# print 10 each with different hierarchy labels and their correpsonding content
hierarchy_labels = df['Hierarchy_Label'].unique()
for label in hierarchy_labels:
    print(f"Label: {label}")
    print("--------------------------------------------------")
    sample = df[df['Hierarchy_Label'] == label].sample(n=30, random_state=42)
    for i, row in sample.iterrows():
        print(f"Email {i}:")
        print("--------------------------------------------------")
        print(row['content'])
        print("--------------------------------------------------")
    print("\n\n")
# Out:
# Label: Sender higher
# --------------------------------------------------
# Email 19879:
# --------------------------------------------------
# Hi Al,
#
# My suggestion is that you capture the change order with change order #1 for
# PSCO's break out contract.  If it needs to be paid before year end (which it
# probably does) you can put a payment date of December 20th, and it will be
# paid out of TurboPark.  This approach has been discussed with Lee Johnson at
# GE, and he is fine with it.
#
# Thanks,
#
# Kay
# --------------------------------------------------
# Email 11766:
# --------------------------------------------------
# We would like to begin trading a new product on EOL.  The location - PG&E
# Topock -  has already been set up, but we would like to make a small change
# to the long description.  The line which reads  -  "The transaction is for
# delivery at PG&E, El Paso."  should be changed to "The transaction is for
# delivery at PG&E Topock"    Please let me know when we can review the change,
# as Mike Grigsby would like to begin trading this product as soon as
# possible.  Thanks.
# --------------------------------------------------
# Email 1720:
# --------------------------------------------------
# Hi again,
#
# Delta Power will be making revisions to the LLC for tax purposes.  I've given
# them your email address to include you in the distribution.
#
# Kay
# --------------------------------------------------
# Email 8350:
# --------------------------------------------------
# So are you not talking to me anymore or something?  I emailed once and called
# twice in the past week and a half  and haven't heard back from you?
# --------------------------------------------------
# Email 20681:
# --------------------------------------------------
# Transwestern's average deliveries to California were 924 MMBtu/d (85%), with San Juan lateral throughput at 849 MMBtu/d.  Total East deliveries averaged 479 MMBtu/d.
#
# El Paso's average deliveries to California were 2146 MMBtu/d (73%):
# - PG&ETop, capacity of 1140 MMBtu/d, deliveries of 716 MMBtu/d (63%)
# - SoCalEhr, capacity 1250 MMBtu/d, deliveries of 985 MMBtu/d (79%)
# - SoCalTop, capacity 540 MMBtu/d, deliveries of 445 MMBtu/d (82%)
#
# Friday's posted Gas Daily prices:
# 	SoCal gas, large pkgs	  1.94 (-.635)
# 	PG&E, large pkgs	  1.855 (-.61)
# 	TW San Juan		  1.62 (-.70)
# 	TW Permian		  1.71 (-.70)
#
# Enron Online bases:
# 		Dec-Mar		Apr-Oct
# Perm-CA	.05 (-.03)	    	.21 (-.02)
# SJ - CA	.20 (even)  	       	.41 (-.03)
# SJ-Waha	.20 (+.04)	       	.26 (+.01)
# Perm-Waha	.05 (+.01)                 	.06 (+.01)
# --------------------------------------------------
# Email 15026:
# --------------------------------------------------
# Transwestern's average deliveries to California were 1044 MMBtu/d (96%), with San Juan lateral throughput at 853 MMBtu/d.  Total East deliveries averaged 453 MMBtu/d.
#
# El Paso's average deliveries to California were 1937 MMBtu/d (66%):
# - PG&ETop, capacity of 1140 MMBtu/d, deliveries of 586 MMBtu/d (51%)
# - SoCalEhr, capacity 1250 MMBtu/d, deliveries of 952 MMBtu/d (76%)
# - SoCalTop, capacity 540 MMBtu/d, deliveries of 399 MMBtu/d (74%)
#
# Friday's posted Gas Daily prices:
# 	SoCal gas, large pkgs	  2.595 (+.02)
# 	PG&E, large pkgs	  2.535 (+.03)
# 	TW San Juan		   n/a
# 	TW Permian		  2.355 (-.12)
#
# Enron Online bases:
# 			Jan		Jan-Mar		Apr-Oct
# Perm-CA		n/a	   	n/a		n/a
# SJ - CA		n/a 		n/a	 	n/a
# SJ-Waha		.10	       	.08		.22
# Perm-Waha		.01                 	.01		.05
# --------------------------------------------------
# Email 2049:
# --------------------------------------------------
# Attached is the September 2000 nomination for our takes under the Gas Sales
# and
# Purchase Contract between TXU Fuels (previously TUFCO) and HPL Resources Co.,
# (TXU Fuels Contr. #3949), as well as our September 2000 nomination for takes
# under the Gas Sales and Purchase Contract between TXU Fuels and SDS.  Please
# advise should you have any questions concerning the attached.
#
#
#
#
# Thanks!
# Tim
#
#
#
#                     (See attached file: MinHPLN00.xls)                 (See
# attached file: SDSNOM.xls)
#
#  - MinHPLN00.xls
#  - SDSNOM.xls
# --------------------------------------------------
# Email 13726:
# --------------------------------------------------
# Rick will hold a conference call on Friday, October 26 to update everyone on what has transpired since last Friday's department call.  The call will take place as follows:
#
# Date:		Friday, October 26
#
# Time:		3:00 PM (CDT)
#
# Number:	1-800-283-1805 (domestic)
# 		703-736-7385 (int'l)
#
# Location:	ECN 4701 (for those in Houston)
#
# Thanks and please call if you have any questions.
#
# Ginger Dernehl
# Administrative Coordinator
# Global Government Affairs
# Phone# 713-853-7751
# Fax# 713-646-8160
# --------------------------------------------------
# Email 10462:
# --------------------------------------------------
# Got your message.  Thanks. I think that 2 hours is the most we'll want to
# take with Freeman.  Might be shorter, but I can't imagine that it would go
# any longer.
#
# Best,
# Jeff
# --------------------------------------------------
# Email 18618:
# --------------------------------------------------
# I think everyone needs a good wife!
# --------------------------------------------------
# Email 10576:
# --------------------------------------------------
# Larry,
#
#  Just a note to touch base on the sagewood townhomes and other development
# opportunities.
#
#  I stumbled across some other duplexes for sale on the same street. that were
# built by Reagan Lehmann.  22 Units were sold for
#  around $2 million. ($182,000/duplex).  I spoke to Reagan and he indicated
# that he had more units under construction that would be
#  available in the 180's.  Are the units he is selling significantly different
# from yours?  He mentioned some of the units are the 1308 floor
#  plan.  My bid of 2.7 million is almost $193,000/duplex.
#
#  As far as being an investor in a new project, I am still very interested.
#
#  Call or email with your thoughts.
#
# Phillip
# --------------------------------------------------
# Email 10896:
# --------------------------------------------------
# Thanks.  Who was able to do it?
#
# Kay
# --------------------------------------------------
# Email 9700:
# --------------------------------------------------
# The prebid meeting is tomorrow from 3:00 to 5:00 in ECS 5075.
# --------------------------------------------------
# Email 18079:
# --------------------------------------------------
# We are pleased to announce the creation of a new group - Asset Marketing -
# within Enron Americas. The Asset Marketing group will have responsibility for
# the asset divestment function within Enron Americas and work with Generation
# Investments on selected portfolio acquisitions as well as managing power
# origination funding requirements with Treasury.
#
# Don Miller will head the Asset Marketing group and will report directly to
# the Office of the Chair, Enron Americas. Joining Don's group will be Stuart
# Zisman.  Stuart was formerly in ENA Legal, having most recently worked on the
# sale of ENA's peaker plants with Don.
#
# Please join us in congratulating Don and Stuart in their new roles.
# --------------------------------------------------
# Email 6396:
# --------------------------------------------------
# Send the docs to Julia.  Mark
# --------------------------------------------------
# Email 13473:
# --------------------------------------------------
# It will be here July 5 through August 25, 2002.  This is a must see event.  If enough of us want to go (must be at least 20) I I can coordinate a group and hopefully, get us really good seats at a bit of a discount.  I plan to shoot for a Sunday matinee.  Meanwhile, I'm going to get exact ticket prices, etc.  I do know that this event is in great demand and that the orchestra tickets range from approximately $78 to $131.  I will also get prices for other parts of Jones Hall.
#
# Also, I am planning to look at Sunday dates in August.
#
# Be so kind as to shoot me an e-mail so that I'll have an idea how many tickets would be involved.
#
# Thanks,
#
# I
#
# Iris S. Waser
# X3-6059
# EB 4749b
#
# --------------------------------------------------
# Email 4155:
# --------------------------------------------------
# PLEASE MARK YOUR CALENDARS AND PLAN TO ATTEND:
#
# T. J. ,
#
# Could you please send out a message to all the traders regarding a meeting that Kevin Presto has requested them to attend on Friday, September 21 from 2 to 5 p.m. in 5c2.
#
# Thank You
#
#
#
#
# Schedule for Fundamental Presentation
#
#    1. Near Term Power Outlook - Steve Gim & Ryan Williams
#
#    2. Transmission - Steve Benchluch  & Hicham Benjelloun
#
#    3. Emissions - Jason Kaniss
#
#    4. API - Gus Giron
#
#    5.  New Generation & AGA - Mauricio Marquez
#
#    6. Nuke Module - Daniel Jenkins
#
#    7. Metastock - Steve Gim
#
#    8. Cubes - Steve Pan/Alen Chen
#
#
#
# --------------------------------------------------
# Email 2071:
# --------------------------------------------------
# Dear Mr. Fujita,
#
# Thank you very much for  the pictures.
#
#  I have talked to RISK and they will be contacting you shortly.
#
# Vince Kaminski
# --------------------------------------------------
# Email 6063:
# --------------------------------------------------
# please call re: dunn.  thx, jeff  415.782.7822.
# --------------------------------------------------
# Email 19094:
# --------------------------------------------------
# We are trying to finish those today and probably will have them for you by
# the end of today.  We have had to tract down some additional environmental
# documents.  Please give us a call if you have any additional questions.
# Thanks!
# Ben
# --------------------------------------------------
# Email 9271:
# --------------------------------------------------
# I do not find any existing agreements for Oglethrope or ACES.
#
# Debra Perlingiere
# Enron North America Corp.
# Legal Department
# 1400 Smith Street, EB 3885
# Houston, Texas 77002
# dperlin@enron.com
# Phone 713-853-7658
# Fax  713-646-3490
# --------------------------------------------------
# Email 6659:
# --------------------------------------------------
# Great job.  Congratulations.
#
# Jeff
# --------------------------------------------------
# Email 21300:
# --------------------------------------------------
# I entered this deal in the system with the wrong term date.  I entered this
# as a Dec-00 deal.  The term is 11/23 - 11/30/2000.
#
# My fault.  I corrected Sitara.
# --------------------------------------------------
# Email 2998:
# --------------------------------------------------
# (See attached file: HPLN0223.xls)
#
#  - HPLN0223.xls
# --------------------------------------------------
# Email 3342:
# --------------------------------------------------
# Kathleen,
#
# Here are two revised Master for your review.  We have agreed to $.05 for the
# penalty section, and I have made other changes to Article1.
#
# Please let me know if you are ready to close.
#
#
#
# Best regards,
# Debra Perlingiere
# Enron North America Corp.
# Legal Department
# 1400 Smith Street, EB 3885
# Houston, Texas 77002
# dperlin@enron.com
# Phone 713-853-7658
# Fax  713-646-3490
# --------------------------------------------------
# Email 415:
# --------------------------------------------------
# Per:
# Can you give the Campbell fund read-only access to EOL.  It may speed up the
# process if they see they can trade pre-market.
# John
# --------------------------------------------------
# Email 17562:
# --------------------------------------------------
# Attached is the final list for name changes and mergers for August 2000.
#
# The name change overlays were done on the dates indicated.
#
# The ERMS short names will be changed TOMORROW, August 23, in the afternoon.
# If there are any objections please contact me or Bill Hare at  X3-9249.
#
# Record inactivations will be done on the afternoon of Sept, 1.
#
#
# Please call Cheryl for questions or comments X3-3103
#
#
# --------------------------------------------------
# Email 12790:
# --------------------------------------------------
# Oops, sorry!  Here they are!
#
# Marie
#
#
#
#
# --------------------------------------------------
# Email 24079:
# --------------------------------------------------
# no survey present when I open site - please advice
# --------------------------------------------------
# Email 751:
# --------------------------------------------------
# Hey Cliff,
#
# Which Rogue Spear do you have?
#
# D
# --------------------------------------------------
#
#
#
# Label: Recipient higher
# --------------------------------------------------
# Email 13649:
# --------------------------------------------------
# Attached are summaries of two recent SoCalGas advice letters.
# ?
# Dan
#  - 10-16-00 SoCalGas AL Summary Chart.doc
# --------------------------------------------------
# Email 18630:
# --------------------------------------------------
#  can you fill in what you know.
# --------------------------------------------------
# Email 17950:
# --------------------------------------------------
# Attached is another redlined draft of the Pastoria IM.  It is much more close
# to completion because it now includes comments from all necessary parties.
#
# Please carefully review and send me any changes no later than Monday.  If you
# send them today (Sunday) send them via e-mail.  Beginning Monday (12 PM CDT)
# I'll be in SF, so if you fax them send them to 415.782.7827.
#
# Please call me at 713.629.0929 or 713.398.6412 should you have any
# questions.  Thanks.
#
#
# PS  for Dave Parquet:  Not all of your proposed changes were made simply
# because I could not ready many of them and the changes were too late at night
# to call you.  I was asked to get a draft out ASAP so I will call you today
# (Sunday) to discuss them.
#
#
#
# --------------------------------------------------
# Email 15028:
# --------------------------------------------------
# Attached please find the OTC margin analysis as requested.
#
# --------------------------------------------------
# Email 8617:
# --------------------------------------------------
# Attached is PIRA's latest "Gas Flash Weekly."
#
# If you have any questions regarding the report's content, please
# contact: Greg Shuttlesworth (email: greg@pira.com), Richard Redash
# (email: Rich@pira.com), Nobu Tarui (email: nobuo@pira.com) or Jane Hsu
# (email: jane@pira.com), at (212) 686-6808.
#
# Contact Client Services regarding PIRA report distribution and address
# changes at (212) 686-6808, email: support@pira.com.
#
# NOTE: Circulation of the "Gas Flash Weekly" outside a Client's licensed
# distribution area is strictly prohibited. Clients that are unsure of
# their licensed distribution or require an extension of their current
# license should contact their PIRA sales representative, or email to
# sales@pira.com.
#
# PIRA Energy Group
#
#
#  - aga121201.pdf
# --------------------------------------------------
# Email 22896:
# --------------------------------------------------
# Chris,
#
#  We are going to redirect 3600 dths off of Texas Gas from CG&E to TCO
# Pool.  600 dths/day will be delivered at Lebanon starting Thursday, February
# 24.
# Please let me know if there are any questions or problems.
#
# Brian
# --------------------------------------------------
# Email 4526:
# --------------------------------------------------
# I appreciate your note and yes it has been awhile since we spoke.  I do chat
# with Ray occasionally.  Steve without sounding abrupt I still have no
# intention of doing business with your shop.  That situation was difficult
# for several of us involved, and it is not something  that I believe I will
# forget. nor understand.
#
#
# Sincerely,
#
# Sandra
# --------------------------------------------------
# Email 11875:
# --------------------------------------------------
# Barry,
#
# As promised, here are some of the current redeployment candidates that have a marketing/structuring/trading background for consideration concerning your West Origination opening.  I believe that you have seen Jim Lowe before and expressed some limited interest in him.  The other candidates are most likely new to you.
#
# Let me know if you would like to pursue any of these redeployed employees.
#
#
#
#
# Also, I spoke with Mark McConnell today, and he mentioned that he had accepted the offer to join the Transwestern group of ETS.  He primary motivation for selection of this option was his desire to work with asset deals.  As we know, given EWS "asset light" approach to deal making, this option would be difficult to fulfill within the West Origination group.  However, he mentioned that he was very impressed with your group, and short of the asset piece maintained a high interest in your open position.
#
# Regards,
# Todd Peikert
# --------------------------------------------------
# Email 18891:
# --------------------------------------------------
# Vince,
# Steve Leppard informed my today that he will be moving to Enron Metals.  I
# think that leaves a leadership hole in Research here.  When that happens in a
# place like this, resources get diverted to the squeakiest wheel.  Do you have
# any advice?  I am concerned that London continues to lag behind in the
# implementation and analysis of VaR - most commodities are on spreadsheets and
# there is not a lot of attention on calibration, analyzing output, refining,
# improving etc..
# pls advise
# ted
# --------------------------------------------------
# Email 18432:
# --------------------------------------------------
#   According to Dan Wilson at Cornbelt there is a peak alert at Hubbard today and tomorow.
# --------------------------------------------------
# Email 10915:
# --------------------------------------------------
#
# This is the Weekly Report covering 7/19-7/25.
#
#
#
# Lex Carroll
# Enron Power Marketing
# Midwest Origination
# 713-853-5426
# --------------------------------------------------
# Email 10919:
# --------------------------------------------------
# NESA/HEA Members:
#
# A couple changes have been made to the April 18th Brown Bag.  Attached is an
# update with the Brown Bag details.
#
# >  <<Complexity Science>>
# >
# We look forward to see you there.  Please contact me with any questions
# (713) 856-6525.
#
# Thanks,
# Lana Moore
#
#
#  - NESA BrownBag Flyer.doc
# --------------------------------------------------
# Email 15155:
# --------------------------------------------------
# This article kind of explains the sentiments of the people seen protesting against the current attacks. Also the article touches briefly on the disastrous effects of siding with America, during cold war, on Pakistan but i think with a lesson from previous experience both countries can do much better this time. Also the government is firmly behind the U.S coalition
# Bilal
#
#
#
#
#
#
#
# <Embedded Picture (Metafile)>
# --------------------------------------------------
# Email 13826:
# --------------------------------------------------
# For the past two production months I have had rate issues with Oasis.  I just talked with Marilyn Gilliam and suggested that Natalie Baker be put on a distribution list so Natalie can work on the rates during the month instead of me coming down at the end of the month and needing rates fixed.  I was informed by Marilyn that we were not sending rates to Oasis and that we should be doing this which would help prevent rate discrepancies at the end of the month.
#
# Mike--if you have any questions about sending the rates to Oasis, you can contact Paul McPheeters at Oasis and he can assist you.
#
# Natalie--this is just an FYI.
#
# Stephen R. Swisher
# Specialist, Energy Operations
# Enron Net Works, LLC
# Phone:  713-345-3042
# Fax:  713-345-7701
# Email:  stephen.swisher@enron.com
# --------------------------------------------------
# Email 9377:
# --------------------------------------------------
# This warning is sent automatically to inform you that your mailbox is approaching the maximum size limit.
# Your mailbox size is currently 82374 KB.
#
# Mailbox size limits:
#
# 	When your mailbox reaches 75000 KB you will receive this message.To check the size of your mailbox:
#
#    Right-click the mailbox (Outlook Today),
#    Select Properties and click the Folder Size button.
#   This method can be used on individual folders as well.
#
# To make more space available, delete any items that are no longer needed such as Sent Items and Journal entries.
#
# You must empty the Deleted Items folder after deleting items or the space will not be freed.
#
# To turn Journaling off,
#   click Tools | Options | Journaling Options and de-select all items.
#
# See client Help for more information.
# --------------------------------------------------
# Email 8895:
# --------------------------------------------------
# hey sue,
#
# glad to hear you enjoyed the trip to tennessee. it sounds extremely
# relaxing. you don't sound too certain about the job in seattle. are
# you not thrilled about it? if not but you really want to be in seattle,
# maybe you could take it on the hope that you may find something
# better in a couple of months. have you been thinking about the
# possibility of tennessee? have you been looking for jobs outside of
# the energy industry?
#
# $350 is great. i told my mom to be expecting you to drop by. if
# shes not there you can tape it to the back door. also, my mom
# said you dropped off the vacuum cleaner... thanks so much.
#
# gotta run, but i will be in touch. keep me posted on all your
# decisions.
#
# Lisa
# --------------------------------------------------
# Email 15054:
# --------------------------------------------------
# Let's meet to discuss capacity release credit checks, prepays and turnaround time for capacity release.  Please let me know if this time conflicts with your schedule.
# --------------------------------------------------
# Email 15019:
# --------------------------------------------------
# Joe -
#
# As a follow up on our meeting last week, I'm working with Rick Causey and
# CAOs for ENA and Enron Europe to identify potential candidates and to refine
# our job description for the local hire we want to recruit permanently.  Rick
# wants to be closely involved in those decisions.  Would you please forward to
# me some of the handouts you had with you or may have updated by now that
# address the business environment, Gantt chart/timeline, office scope, timing
# of business transactions etc. to aid in communicating Tokyo needs?  I'm not
# sure if you sent anything to Sally, but I don't believe I've seen anything
# yet.
#
# Thank you,
#
# Cassandra.
# --------------------------------------------------
# Email 15116:
# --------------------------------------------------
# Jeff appeared live on CNBC "Street Signs" to talk about Enron's stock.  Go to
# eBiz and read what he had to say.
#
# Also in this issue:
# Enron snags more awards
# 1,001 (not really) things to do with Pulse lights
# Who in the world is Henry Hub?
#
# It's all in the latest eBiz.  Go to home.enron.com, click Publications, then
# click eBiz, and "eBiz December 1, 2000."
# --------------------------------------------------
# Email 7727:
# --------------------------------------------------
#
#  Attached is a preliminary "Buyback & Deficiency Deals" worksheet  for July
# 2000 activity.
#
#
#
# --------------------------------------------------
# Email 6669:
# --------------------------------------------------
# John,
#
# Please be advised that effective Monday, December 4 you will need to access
# DynegyDirect with the following log in:
#
# User ID:  JLAVORATO
# Password: enron1
#
# Please note that these are case sensitive.
#
# Your current log in will no longer be available on Monday.
#
# Thank you,
# Stephanie Sever x33465
# --------------------------------------------------
# Email 3070:
# --------------------------------------------------
# tom:
# attached please find the confidential job descriptions that we have been
# retained to work on for exelon power team.
# please advise on how you would like to proceed.
# i have additional information from their vp if you would like to discuss
# further.
# best regards,
# todd j. goehring
# --------------------------------------------------
# Email 13606:
# --------------------------------------------------
#
# You won't believe your eyes....
#
#
# --------------------------------------------------
# Email 20397:
# --------------------------------------------------
# This week's Lite Bytz presentation scheduled for Thursday, May 31, 2001 is
# CANCELLED due to illness.  We will reschedule Bob McAulliffe's Command
# Center presentation soon.
#
# --------------------------------------------------
# Email 15265:
# --------------------------------------------------
# (See attached file: HPLN0220.xls)
#
#  - HPLN0220.xls
# --------------------------------------------------
# Email 15541:
# --------------------------------------------------
# Gerald!
#
# Kindly issue an amendment to our out-going guaranty for the benefit of Tractebel Energy Marketing, Inc., executed in May 2000.  We are requesting an increase to $10.00MM.
#
# The increase is to provide support to an existing deal and the counterparty would like to have this amendment as soon as possible.
#
#
# Thank you for your cooperation.
#
# Rudwell
# 53596.
# --------------------------------------------------
# Email 11586:
# --------------------------------------------------
# Dear Mr. LARRY CAMPBELL:
#
# Thank you for your order.
#
# You bought 20 shares of JNPR (Juniper Networks Inc Com) at 182.000000.
#
# ORDER DETAILS:
# The tracking number for this order is: B-300-AAYY-7964
# Order entered at:                      12:05:30 on 11/15/00
# Order processing began at:             12:05:31
# Order executed at:                     12:05:31 on 11/15/00
#
# ACCOUNT DETAILS:
# Time and Date: 12:05:32 on 11/15/00
# Your position in JNPR is -59 shares
# Your real cash total is $20,210.79
#
# You will receive a printed Datek Online confirmation by postal mail, or by
# electronic delivery if you are subscribed to that service.
#
# Questions regarding this transaction? Contact our Customer Support department
# by e-mailing support@datek.com. Please reference the order tracking number.
#
# --------------------------------------------------
# Email 7401:
# --------------------------------------------------
# Lloyd,
#
# Please find below update information to the New Generation Project.  If you
# have any questions or comments, feel free to contact me (x39844) or Kristin
# (x39510).
#
#
#
#
#
#
# Thanks,
# Kelly
#
#
# --------------------------------------------------
# Email 13874:
# --------------------------------------------------
# eSource presents free Dow Jones Interactive training
#
# Introduction to Dow Jones Interactive
# Learn about the content available through Dow Jones Interactive, and how to
# quickly put it to work for you. Including setting up your own custom clips
# and monitoring topics of interest to you.
#
# June. 8   9:00 - 10:00 AM  EB560
#
# Advanced
# Learn how to be more efficient on Dow Jones Interactive.  Put some power
# tools to work for you.  Learn how to employ codes, use search history, and
# customize.  Hands on time is provided.
#
#    June. 8   10:00 - 11:00 AM  EB560
#   June. 8     11:00 - 12:00 AM  EB560
#
# Seats fill up fast! To reserve a seat, please call Stephanie E. Taylor at
# 5-7928
#
# ? No Shows will be charged $50.00
#
# Check the eSource training page at http://esource.enron.com/training.doc for
# additional training sessions and vendor presentations
#
# http://esource.enron.com
#
#
#
# --------------------------------------------------
# Email 20327:
# --------------------------------------------------
# I just wanted to let you know that if there is anything I can do to help I am more than willing to do it.  These are difficult times and I am doing alot of floor meetings and table talks with the employees.  They clearly do not understand how we got into this situation and just want some face time with Management.  With the exception of NEPCO our fourth quarter looks good.  I have uncovered alot of issues with NEPCO that I do not think anyone knew existed.  I'll know more Friday after a businnes/budget review session.
#
# Please let me know if I can help.
#
# Stan
# --------------------------------------------------
#
#
#
# Label: Similar level
# --------------------------------------------------
# Email 11356:
# --------------------------------------------------
# Start Date: 4/21/01; HourAhead hour: 21;  No ancillary schedules awarded.  No
# variances detected.
#
#     LOG MESSAGES:
#
# PARSING FILE -->> O:\Portland\WestDesk\California Scheduling\ISO Final
# Schedules\2001042121.txt
#
# ---- Generation Schedule ----
# *** Final schedule not found for preferred schedule.
#      Details:
#
#   TRANS_TYPE: FINAL
#   SC_ID: HARBOR
#   MKT_TYPE: 2
#   TRANS_DATE: 4/21/01
#   UNIT_ID: HARBGN_7_UNITS
#
#
# --------------------------------------------------
# Email 21190:
# --------------------------------------------------
# Start Date: 2/27/01; HourAhead hour: 15;  No ancillary schedules awarded.
# Variances detected.
# Variances detected in Load schedule.
#
#     LOG MESSAGES:
#
# PARSING FILE -->> O:\Portland\WestDesk\California Scheduling\ISO Final
# Schedules\2001022715.txt
#
# ---- Load Schedule ----
# $$$ Variance found in table tblLoads.
#      Details: (Hour: 15 / Preferred: 165.67 / Final: 164.67)
#   TRANS_TYPE: FINAL
#   LOAD_ID: SCE1
#   MKT_TYPE: 2
#   TRANS_DATE: 2/27/01
#   SC_ID: EPMI
#
#
# --------------------------------------------------
# Email 4559:
# --------------------------------------------------
#
#
# Start Date: 1/6/02; HourAhead hour: 18;  No ancillary schedules awarded.  No variances detected.
#
#     LOG MESSAGES:
#
# PARSING FILE -->> O:\Portland\WestDesk\California Scheduling\ISO Final Schedules\2002010618.txt
# --------------------------------------------------
# Email 11425:
# --------------------------------------------------
# Start Date: 4/17/01; HourAhead hour: 18;  No ancillary schedules awarded.
# Variances detected.
# Variances detected in Load schedule.
#
#     LOG MESSAGES:
#
# PARSING FILE -->> O:\Portland\WestDesk\California Scheduling\ISO Final
# Schedules\2001041718.txt
#
# ---- Load Schedule ----
# $$$ Variance found in table tblLoads.
#      Details: (Hour: 18 / Preferred:   9.46 / Final:   9.45)
#   TRANS_TYPE: FINAL
#   LOAD_ID: SCE1
#   MKT_TYPE: 2
#   TRANS_DATE: 4/17/01
#   SC_ID: EPMI
#
#
# --------------------------------------------------
# Email 23577:
# --------------------------------------------------
# Start Date: 4/25/01; HourAhead hour: 6;  No ancillary schedules awarded.
# Variances detected.
# Variances detected in SC Trades schedule.
#
#     LOG MESSAGES:
#
# PARSING FILE -->> O:\Portland\WestDesk\California Scheduling\ISO Final
# Schedules\2001042506.txt
#
# ---- SC Trades Schedule ----
# $$$ Variance found in table tblInt_Interchange.
#      Details: (Hour: 6 / Preferred: -575.00 / Final: -574.97)
#   TRANS_TYPE: FINAL
#   SC_ID: EPMI
#   MKT_TYPE: 2
#   TRANS_DATE: 4/25/01
#   TRADING_SC: NES1
#   PNT_OF_INTRC: SP15
#   SCHED_TYPE: ENGY
#   PURCH_SALE: 1
#   DEAL_NO: 1
#
#
# --------------------------------------------------
# Email 18625:
# --------------------------------------------------
# Start Date: 4/12/01; HourAhead hour: 6;  HourAhead schedule download failed.
# Manual intervention required.
# --------------------------------------------------
# Email 14909:
# --------------------------------------------------
#
#
# Start Date: 1/15/02; HourAhead hour: 7;  HourAhead schedule download failed. Manual intervention required.
# --------------------------------------------------
# Email 10833:
# --------------------------------------------------
#
# Attached please find the Natural Gas market  analysis for today.
#
# Thanks,
#
# Bob McKinney
#  - 5-31-01 Nat Gas.doc
# --------------------------------------------------
# Email 1884:
# --------------------------------------------------
# Start Date: 4/21/01; HourAhead hour: 24;  No ancillary schedules awarded.
# Variances detected.
# Variances detected in Generation schedule.
# Variances detected in Load schedule.
#
#     LOG MESSAGES:
#
# PARSING FILE -->> O:\Portland\WestDesk\California Scheduling\ISO Final
# Schedules\2001042124.txt
#
# ---- Generation Schedule ----
# *** Final schedule not found for preferred schedule.
#      Details:
#
#   TRANS_TYPE: FINAL
#   SC_ID: HARBOR
#   MKT_TYPE: 2
#   TRANS_DATE: 4/21/01
#   UNIT_ID: HARBGN_7_UNITS
# $$$ Variance found in table tblGEN_SCHEDULE.
#      Details: (Hour: 24 / Preferred:  29.00 / Final:  28.97)
#   TRANS_TYPE: FINAL
#   SC_ID: ARCO
#   MKT_TYPE: 2
#   TRANS_DATE: 4/21/01
#   UNIT_ID: CARBGN_6_UNIT 1
#
#
#
# ---- Load Schedule ----
# $$$ Variance found in table tblLoads.
#      Details: (Hour: 24 / Preferred:   4.83 / Final:   4.80)
#   TRANS_TYPE: FINAL
#   LOAD_ID: PGE2
#   MKT_TYPE: 2
#   TRANS_DATE: 4/21/01
#   SC_ID: EPMI
#
#
# --------------------------------------------------
# Email 2461:
# --------------------------------------------------
# Start Date: 4/14/01; HourAhead hour: 4;  No ancillary schedules awarded.  No
# variances detected.
#
#     LOG MESSAGES:
#
# PARSING FILE -->> O:\Portland\WestDesk\California Scheduling\ISO Final
# Schedules\2001041404.txt
# --------------------------------------------------
# Email 8368:
# --------------------------------------------------
#
#
#
# My complete and heart-felt condolences go  out to all my American friends. India shares your grief. I only hope that out of  this calamity, America's wrath shall bring retribution without end.
#
# Annat Jain
# --------------------------------------------------
# Email 20031:
# --------------------------------------------------
# Start Date: 3/8/01; HourAhead hour: 4;  No ancillary schedules awarded.  No
# variances detected.
#
#     LOG MESSAGES:
#
# PARSING FILE -->> O:\Portland\WestDesk\California Scheduling\ISO Final
# Schedules\2001030804.txt
#
# ---- Generation Schedule ----
# *** Final schedule not found for preferred schedule.
#      Details:
#
#   TRANS_TYPE: FINAL
#   SC_ID: WheelSHAST
#   MKT_TYPE: 2
#   TRANS_DATE: 3/8/01
#   UNIT_ID: WSENGY_1_UNIT 4
#
#
# --------------------------------------------------
# Email 3974:
# --------------------------------------------------
# Start Date: 4/25/01; HourAhead hour: 23;  No ancillary schedules awarded.  No
# variances detected.
#
#     LOG MESSAGES:
#
# PARSING FILE -->> O:\Portland\WestDesk\California Scheduling\ISO Final
# Schedules\2001042523.txt
# --------------------------------------------------
# Email 21236:
# --------------------------------------------------
# You are now on the Wait List for Wellhead to Burner Tip, beginning on April
# 24 - 25, 2001
# If space becomes available, you will be notified by e-mail.
#
# If you have any questions, please call the Development Center Team at
# 713-853-0357.
#
# Thank you.
# --------------------------------------------------
# Email 20068:
# --------------------------------------------------
# Start Date: 4/15/01; HourAhead hour: 19;  No ancillary schedules awarded.
# Variances detected.
# Variances detected in Load schedule.
#
#     LOG MESSAGES:
#
# PARSING FILE -->> O:\Portland\WestDesk\California Scheduling\ISO Final
# Schedules\2001041519.txt
#
# ---- SC Trades Schedule ----
# *** Final schedule not found for preferred schedule.
#      Details:
#
#   TRANS_TYPE: FINAL
#   SC_ID: EPMI
#   MKT_TYPE: 2
#   TRANS_DATE: 4/15/01
#   TRADING_SC: SETC
#   PNT_OF_INTRC: NP15
#   SCHED_TYPE: ENGY
#   PURCH_SALE: 1
#   DEAL_NO: 1
#
#
#
# ---- Load Schedule ----
# $$$ Variance found in table tblLoads.
#      Details: (Hour: 19 / Preferred: 112.64 / Final: 112.64)
#   TRANS_TYPE: FINAL
#   LOAD_ID: SDG1
#   MKT_TYPE: 2
#   TRANS_DATE: 4/15/01
#   SC_ID: EPMI
#
#
# --------------------------------------------------
# Email 8268:
# --------------------------------------------------
# Hey thanks for coming out to see the boys the other night, if you weren't there you missed a good show.  24BOM will probably play with Junco Parker again.  But more important than that is Thursday night at the Medicine Hat Gallery- 18th and Alberta St-  9:00 PM.  Show up and give some support, 24BOM will be recording live that night and it would be great to have some crowd response on that cd!!
#
# Thanks again for your support- hope to see you there
#
#
#
#
#
#
#
#
#
#
#
#
# --------------------------------------------------
# Email 13627:
# --------------------------------------------------
# Start Date: 4/18/01; HourAhead hour: 5;  No ancillary schedules awarded.  No
# variances detected.
#
#     LOG MESSAGES:
#
# PARSING FILE -->> O:\Portland\WestDesk\California Scheduling\ISO Final
# Schedules\2001041805.txt
#
# ---- Energy Import/Export Schedule ----
# *** Final schedule not found for preferred schedule.
#      Details:
#
#   TRANS_TYPE: FINAL
#   SC_ID: ECTRT
#   MKT_TYPE: 2
#   TRANS_DATE: 4/18/01
#   TIE_POINT: FCORNR_5_PSUEDO
#   INTERCHG_ID: EPMI_CISO_DESERT
#   ENGY_TYPE: FIRM
#
#
# --------------------------------------------------
# Email 7203:
# --------------------------------------------------
# Start Date: 4/11/01; HourAhead hour: 16;  No ancillary schedules awarded.
# Variances detected.
# Variances detected in Load schedule.
#
#     LOG MESSAGES:
#
# PARSING FILE -->> O:\Portland\WestDesk\California Scheduling\ISO Final
# Schedules\2001041116.txt
#
# ---- Load Schedule ----
# $$$ Variance found in table tblLoads.
#      Details: (Hour: 16 / Preferred:   2.27 / Final:   2.26)
#   TRANS_TYPE: FINAL
#   LOAD_ID: PGE4
#   MKT_TYPE: 2
#   TRANS_DATE: 4/11/01
#   SC_ID: EPMI
#
#
# --------------------------------------------------
# Email 18519:
# --------------------------------------------------
# Start Date: 4/17/01; HourAhead hour: 8;  No ancillary schedules awarded.  No
# variances detected.
#
#     LOG MESSAGES:
#
# PARSING FILE -->> O:\Portland\WestDesk\California Scheduling\ISO Final
# Schedules\2001041708.txt
# --------------------------------------------------
# Email 6422:
# --------------------------------------------------
# Start Date: 4/20/01; HourAhead hour: 6;  No ancillary schedules awarded.
# Variances detected.
# Variances detected in Load schedule.
#
#     LOG MESSAGES:
#
# PARSING FILE -->> O:\Portland\WestDesk\California Scheduling\ISO Final
# Schedules\2001042006.txt
#
# ---- Load Schedule ----
# $$$ Variance found in table tblLoads.
#      Details: (Hour: 6 / Preferred:  44.21 / Final:  44.18)
#   TRANS_TYPE: FINAL
#   LOAD_ID: PGE3
#   MKT_TYPE: 2
#   TRANS_DATE: 4/20/01
#   SC_ID: EPMI
#
#
# --------------------------------------------------
# Email 11053:
# --------------------------------------------------
#
#
# Start Date: 1/6/02; HourAhead hour: 19;  No ancillary schedules awarded.  No variances detected.
#
#     LOG MESSAGES:
#
# PARSING FILE -->> O:\Portland\WestDesk\California Scheduling\ISO Final Schedules\2002010619.txt
# --------------------------------------------------
# Email 6326:
# --------------------------------------------------
#
#
# Start Date: 10/14/01; HourAhead hour: 4;  No ancillary schedules awarded.  No variances detected.
#
#     LOG MESSAGES:
#
# PARSING FILE -->> O:\Portland\WestDesk\California Scheduling\ISO Final Schedules\2001101404.txt
#
# Error retrieving HourAhead price data - process continuing...
# --------------------------------------------------
# Email 20761:
# --------------------------------------------------
# Start Date: 4/19/01; HourAhead hour: 23;  HourAhead schedule download failed.
# Manual intervention required.
#
#     LOG MESSAGES:
#
# PARSING FILE -->> O:\Portland\WestDesk\California Scheduling\ISO Final
# Schedules\2001041923.txt
#
# Error: dbCapsPMIData: Cannot perform this operation on a closed database
# Error retrieving price data (General SQL error.
# Unrecognized database format 'R:\EnpowerCAPS\CAPS97DATA.mdb'.
# Table) - process continuing...
# --------------------------------------------------
# Email 22999:
# --------------------------------------------------
# (See attached file: newdaily.pdf)
#
#
#
#
#
#
#
#
#
#       Carr Futures
#       150 S. Wacker Dr., Suite 1500
#       Chicago, IL 60606  USA
#       Tel:  312-368-6149
#       Fax:  312-368-2281
#       soblander@carrfut.com
#       http://www.carrfut.com
#  - newdaily.pdf
# --------------------------------------------------
# Email 5014:
# --------------------------------------------------
#
#
# Start Date: 1/28/02; HourAhead hour: 12;  No ancillary schedules awarded.  No variances detected.
#
#     LOG MESSAGES:
#
# PARSING FILE -->> O:\Portland\WestDesk\California Scheduling\ISO Final Schedules\2002012812.txt
# --------------------------------------------------
# Email 20131:
# --------------------------------------------------
# The information contained herein is based on sources that we believe to be
# reliable, but we do not represent that it is accurate or complete.  Nothing
# contained herein should be considered as an offer to sell or a solicitation
# of an offer to buy any financial instruments discussed herein.  Any
# opinions expressed herein are solely those of the author.  As such, they
# may differ in material respects from those of, or expressed or published by
# on behalf of Carr Futures or its officers, directors, employees or
# affiliates.  , 2001 Carr Futures
#
#
# The charts are now in the most recent version of Adobe Acrobat 4.0 and they
# should print clearly from Adobe Acrobat Reader 3.0 or higher. Adobe Acrobat
# Reader 4.0 may be downloaded for FREE from www.adobe.com.
#
# (See attached file: opec.pdf)
#
#
# Carr Futures
# 150 S. Wacker Dr., Suite 1500
# Chicago, IL 60606  USA
# Tel:  312-368-6149
# Fax:  312-368-2281
# soblander@carrfut.com
# http://www.carrfut.com
#  - opec.pdf
# --------------------------------------------------
# Email 16302:
# --------------------------------------------------
#
#
# Start Date: 1/30/02; HourAhead hour: 15;  No ancillary schedules awarded.  No variances detected.
#
#     LOG MESSAGES:
#
# PARSING FILE -->> O:\Portland\WestDesk\California Scheduling\ISO Final Schedules\2002013015.txt
# --------------------------------------------------
# Email 23661:
# --------------------------------------------------
# Start Date: 4/30/01; HourAhead hour: 7;  No ancillary schedules awarded.
# Variances detected.
# Variances detected in Load schedule.
#
#     LOG MESSAGES:
#
# PARSING FILE -->> O:\Portland\WestDesk\California Scheduling\ISO Final
# Schedules\2001043007.txt
# Error: Invalid variant type conversion
#
# ---- Energy Import/Export Schedule ----
# *** Final schedule not found for preferred schedule.
#      Details:
#
#   TRANS_TYPE: FINAL
#   SC_ID: ECTstCA
#   MKT_TYPE: 2
#   TRANS_DATE: 4/30/01
#   TIE_POINT: PVERDE_5_DEVERS
#   INTERCHG_ID: EPMI_CISO_5001
#   ENGY_TYPE: FIRM
#
#
#
# ---- Load Schedule ----
# $$$ Variance found in table tblLoads.
#      Details: (Hour: 7 / Preferred:   6.40 / Final:   6.30)
#   TRANS_TYPE: FINAL
#   LOAD_ID: SCE1
#   MKT_TYPE: 2
#   TRANS_DATE: 4/30/01
#   SC_ID: EPMI
#
#
# --------------------------------------------------
# Email 882:
# --------------------------------------------------
# Start Date: 3/5/01; HourAhead hour: 18;  No ancillary schedules awarded.  No
# variances detected.
#
#     LOG MESSAGES:
#
# PARSING FILE -->> O:\Portland\WestDesk\California Scheduling\ISO Final
# Schedules\2001030518.txt
# --------------------------------------------------
# Email 776:
# --------------------------------------------------
#
#
# Start Date: 2/4/02; HourAhead hour: 3;  No ancillary schedules awarded.  No variances detected.
#
#     LOG MESSAGES:
#
# PARSING FILE -->> O:\Portland\WestDesk\California Scheduling\ISO Final Schedules\2002020403.txt
# --------------------------------------------------
